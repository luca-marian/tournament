# %%
# import time
# import requests
# import json
# import pandas as pd

# base_url = "http://116.202.111.229:8000"
# api_key = "VPLrVk4hSZMdGrW2wAP0GTpsV2Jsdx5Z"

# headers = {"x-api-key": api_key}

# rounds = 5
# current_round = 1
# examples = []
# while True:
#     # Get a new hint for current company or get the first hint for a new company after calling /evaluate/reset

#     tmp_dict = {}
#     tmp_company_id = None
#     while current_round != 6:
#         response = requests.get(f"{base_url}/evaluate/hint", headers=headers)

#         print(response.status_code, response.json())

#         obj_hint = response.json()

#         if tmp_company_id is None:
#             tmp_company_id = obj_hint["company_id"]

#         if tmp_company_id != obj_hint["company_id"]:
#             current_round = 1
#             tmp_dict = {}
#             tmp_company_id = None

#         # predict based off given hint
#         time.sleep(1)

#         # Post your answer for current hint
#         data = {"answer": "abstain"}
#         response = requests.post(
#             f"{base_url}/evaluate/answer", json=data, headers=headers
#         )

#         print(response.status_code, response.json())

#         obj_eval = response.json()

#         if tmp_dict:
#             tmp_dict.update(
#                 {
#                     "round_" + str(current_round): obj_hint["hint"],
#                 }
#             )
#         else:

#             tmp_dict = {
#                 "company_id": obj_hint["company_id"],
#                 "round_" + str(current_round): obj_hint["hint"],
#                 "answer": obj_eval["answer"],
#             }

#         print(current_round)
#         print(tmp_dict)

#         # print keys of response.json()
#         # for key in response.json().keys():
#         #     print(key)

#         print("")

#         current_round = current_round + 1
#         time.sleep(1)

#     print(tmp_dict)

#     with open(
#         "companies/" + str(tmp_dict["company_id"]) + ".json", "w", encoding="utf-8"
#     ) as f:
#         json.dump(tmp_dict, f, ensure_ascii=False, indent=4)

#     examples.append(tmp_dict)
#     tmp_df = pd.DataFrame(examples)
#     tmp_df.to_csv("companies/data.csv")
#     print(
#         "----------------------------------------------------------------------------\n"
#     )

#     # Get hints about a new company
#     current_round = 1
#     response = requests.get(f"{base_url}/evaluate/reset", headers=headers)

#     print(response.status_code, response.json())

#     # sleep 5 min and 10 seconds
#     time.sleep(300)  # 5 min 10 sec

# %%
import pandas as pd
import os

# %%
test_data = pd.read_csv(
    "/Users/marianluca/Projects/HackingBigNumbers/Tournament/marian/test_data1.csv"
)
test_data.drop(columns=["Unnamed: 0"],inplace=True,axis=1)

# %%
test_data
# Out:
#      company_id                                    commercial_name  \
# 0            84                                      Advisory Care
# 1           115                               PPK Mining Equipment
# 2            50                             First Tracks Lawn Care
# 3            92                              New Golden Furnishers
# 4            88                                  Lilac City Septic
# ..          ...                                                ...
# 101          28                                        Purple Pixl
# 102         116                                     Pasargad Jonub
# 103           6                            Davis Business Machines
# 104          24                                   High Desert Tool
# 105           5  Heart to Heart International is a non-profit o...
#
#                                               answer  \
# 0                621 Ambulatory Health Care Services
# 1                  213 Support Activities for Mining
# 2            561 Administrative and Support Services
# 3    337 Furniture and Related Product Manufacturing
# 4      562 Waste Management and Remediation Services
# ..                                               ...
# 101                       811 Repair and Maintenance
# 102     237 Heavy and Civil Engineering Construction
# 103          423 Merchant Wholesalers, Durable Goods
# 104   326 Plastics and Rubber Products Manufacturing
# 105                            624 Social Assistance
#
#                                          business_tags  \
# 0    Hygiene Services | One-on-one Attention and Ca...
# 1    High & Low Seam Drills | Ventilation Solutions...
# 2    Weekly Mowing | Driveway Plowing Services | Mu...
# 3    Staff Task Computer Chairs Supplier | Mesh Bac...
# 4    Clean-Out Installation | Line Replacement Serv...
# ..                                                 ...
# 101  Battery Replacement | Viruses Removal | Front ...
# 102  Infrastructure Project Management | Design and...
# 103  Managed IT Services | Document Scanners | Fax ...
# 104  Aerospace Molds Supplier | Automotive Molds Di...
# 105                             Social Services & NGOs
#
#                                      short_description  \
# 0    Advisory Care is a home health care services p...
# 1    PPK Mining Equipment is the solution partner o...
# 2    First Tracks Lawn Care, LLC prides itself on p...
# 3    New Golden Furnishers Co - Manufacturer of Dou...
# 4    Lilac City Septic services residential & comme...
# ..                                                 ...
# 101  Purple Pixl offers fast & effective repair ser...
# 102  Having a brilliant background and well-trained...
# 103  Since May 13, 1963, Davis Business Machines ha...
# 104  High Desert Tool specializes in large mold man...
# 105                                     Heart to Heart
#
#                                            description  \
# 0    Advisory Care Pty Ltd is a company that provid...
# 1    PPK Mining Equipment is a company that special...
# 2    First Tracks Lawn Care, LLC is a lawn care com...
# 3    New Golden Furnishers Co is a furniture manufa...
# 4    Lilac City Septic Services Co is a family-owne...
# ..                                                 ...
# 101  Purple Pixl is a technology and electronics re...
# 102  Pasargad Jonub is a private joint stock compan...
# 103  Davis Business Machines is a company that has ...
# 104  High Desert Tool is a company that specializes...
# 105  Global Health Information Provider | Humanitar...
#
#                                 main_business_category  naics_code  \
# 0                                     Home Health Care         621
# 1                             Mining & Gas Exploration         213
# 2                          Landscaping & Lawn Services         561
# 3                                     Office Furniture         337
# 4                  Garbage Collection & Waste Disposal         562
# ..                                                 ...         ...
# 101                            Phone Repair & Services         811
# 102                         Civil Engineering Services         237
# 103                                    Office Supplies         423
# 104                         Injection Molding Services         326
# 105  As a healthcare nonprofit organization, Heart ...         624
#
#                                      naics_label
# 0                Ambulatory Health Care Services
# 1                  Support Activities for Mining
# 2            Administrative and Support Services
# 3    Furniture and Related Product Manufacturing
# 4      Waste Management and Remediation Services
# ..                                           ...
# 101                       Repair and Maintenance
# 102     Heavy and Civil Engineering Construction
# 103          Merchant Wholesalers, Durable Goods
# 104   Plastics and Rubber Products Manufacturing
# 105                            Social Assistance
#
# [106 rows x 9 columns]

# %%
import json
f = open(
    "map_business_to_naics.json"
)
label_dict = json.load(f)

def map_bussines_to_naics(taxonomy:str):
    return label_dict.get(taxonomy, "Not Found")

# naics_label = map_bussines_to_naics("Gyms, Fitness & Health Centers")
