# %%
import pandas as pd

naics_df = pd.read_csv("data/naics_summary.csv")
business_df = pd.read_excel("data/business_category_taxonomy.xlsx")

# %%
import spacy
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re
import string

# Load spaCy model
nlp = spacy.load("en_core_web_md")


def remove_mentions_and_hashtags(text):
    text = re.sub(r"@\w+", "", text)
    text = re.sub(r"#\w+", "", text)
    return text


def remove_numbers(text):
    text = re.sub(r"\d+", "", text)
    return text


def remove_punctuation(text):

    translator = str.maketrans("", "", string.punctuation)

    # Remove punctuation using the translation table
    text_without_punct = text.translate(translator)

    return text_without_punct


def remove_stopwords(text):
    filtered_sentence = []
    doc = nlp(text)
    for token in doc:
        if token.is_stop == False:
            filtered_sentence.append(token.text)
    return " ".join(filtered_sentence)


def lemmatize(text):
    doc = nlp(text)
    text = " ".join([token.lemma_ for token in doc])
    return text


# Define the text cleaning and preprocessing functions
def clean_text(text, to_lemmatize: bool = True):
    text = re.sub(r"http\S+", "", text)  # Remove URLs
    text = remove_mentions_and_hashtags(text)
    text = text.lower()
    text = remove_punctuation(text)
    text = remove_numbers(text)
    text = re.sub(r"\W", " ", text)
    text = re.sub(r"\s+", " ", text, flags=re.I)
    if to_lemmatize:
        text = lemmatize(text)
    return text


# Function to extract key terms using TF-IDF
def extract_top_keywords(texts, n=10):
    vectorizer = TfidfVectorizer(ngram_range=(1, 2), stop_words="english")
    X = vectorizer.fit_transform(texts)
    top_n_keywords = []
    for row in X:
        row_array = row.toarray().flatten()
        top_indices = np.argsort(row_array)[-n:]  # Indices of top n scores
        top_features = [vectorizer.get_feature_names_out()[i] for i in top_indices]
        top_n_keywords.append(top_features)
    return top_n_keywords

# Clean descriptions
business_df["clean_description"] = business_df["description"].apply(clean_text)
naics_df["clean_description"] = naics_df["description"].apply(clean_text)

# Extract top 10 keywords from descriptions
business_df["keywords"] = business_df["clean_description"].apply(
    lambda x: extract_top_keywords([x], 10)[0]
)
naics_df["keywords"] = naics_df["clean_description"].apply(
    lambda x: extract_top_keywords([x], 10)[0]
)

# Convert keywords list to single string per description
business_df["keywords_str"] = business_df["keywords"].apply(" ".join)
naics_df["keywords_str"] = naics_df["keywords"].apply(" ".join)

# Vectorize and calculate cosine similarity
vectorizer = TfidfVectorizer()
all_keywords = list(naics_df["keywords_str"]) + list(business_df["keywords_str"])
vectorizer.fit(all_keywords)
naics_vectors = vectorizer.transform(naics_df["keywords_str"])
business_vectors = vectorizer.transform(business_df["keywords_str"])
similarity_matrix = cosine_similarity(business_vectors, naics_vectors)

# Find the best NAICS match for each business label based on highest similarity
match_indices = np.argmax(similarity_matrix, axis=1)
business_df["matched_naics_label"] = naics_df["naics_label"].values[match_indices]
business_df["similarity_score"] = np.max(similarity_matrix, axis=1)

# %%
final_data = pd.read_csv("data/clean_description.csv")
final_data
# Out:
#                 commercial_name  \
# 0                   White Horse
# 1      Wealth Solution Partners
# 2                           PMG
# 3              TMP Capital PLLC
# 4                Genertek Power
# ...                         ...
# 99995            Karma Hardware
# 99996             Rainbow Paper
# 99997     Blue Support Services
# 99998           Digital Citizen
# 99999            Wendy Hilliard
#
#                                            business_tags  \
# 0      Tile Manufacturing | European Aesthetics Ceram...
# 1      Super and SMSF Services | Financial Planning a...
# 2      Fire and Water Cleanup Services | Mold Remedia...
# 3      Licensed in AL & FL | 203K Loans | 15-year Fix...
# 4      Industrial and Commercial Energy Storage | Ass...
# ...                                                  ...
# 99995  Wholesale | Brass Hook Marble Tower Bolt | Coa...
# 99996  Bulky Newsprint | Parchment Paper & Parchment ...
# 99997  24/7 Facility Management | Building Maintenanc...
# 99998  Bespoke Resourcing Solutions | Cross-platform ...
# 99999  Sports Organization | Competition Teams | Gymn...
#
#                                        short_description  \
# 0      White Horse is highly regarded as a tile trail...
# 1      WSP, Wealth Solution Partners, Financial Plann...
# 2      PMG General Solutions Inc. is an environmental...
# 3      TMP Capital PLLC Consulting Company Franklin M...
# 4      Genertek Power Ltd a UK electricity systems & ...
# ...                                                  ...
# 99995  Karma Hardware - Manufacturer of Door Hinges, ...
# 99996  Rainbow Paper offers a huge selection of art &...
# 99997  Blue Support Services provides a flexible and ...
# 99998  Digital Citizen is a NYC-based digital product...
# 99999  Alexis now studies biology at Hunter College a...
#
#                                              description  \
# 0      White Horse Ceramic Singapore is a leading man...
# 1      Wealth Solution Partners Pty Ltd is an indepen...
# 2      PMG General Solutions Inc. is an environmental...
# 3      TMP Capital PLLC Consulting Company, also know...
# 4      Genertek Power Limited is a privately-owned UK...
# ...                                                  ...
# 99995  Karma Hardware is a manufacturer based in Koth...
# 99996  Rainbow Paper is an Australian-owned brand tha...
# 99997  Blue Support Services is a company that offers...
# 99998  Digital Citizen is a New York City-based digit...
# 99999  The Wendy Hilliard Gymnastics Foundation is a ...
#
#                             main_business_category  best_match_label_index  \
# 0                                       Tile Store                      31
# 1      Investment Consultants & Financial Advisors                      64
# 2            Damage Restoration & Mold Remediation                      84
# 3                                 Mortgage Brokers                      64
# 4                       Renewable energy companies                       8
# ...                                            ...                     ...
# 99995                              Hardware Stores                      37
# 99996                   Paper & Cardboard Products                      20
# 99997            Security Guards & Patrol Services                      64
# 99998                 Digital & Marketing Agencies                      72
# 99999                                   Gymnastics                      70
#
#                                         best_match_label  \
# 0            Furniture and Related Product Manufacturing
# 1      Securities, Commodity Contracts, and Other Fin...
# 2                                 Repair and Maintenance
# 3      Securities, Commodity Contracts, and Other Fin...
# 4                                              Utilities
# ...                                                  ...
# 99995  Building Material and Garden Equipment and Sup...
# 99996            Printing and Related Support Activities
# 99997  Securities, Commodity Contracts, and Other Fin...
# 99998                Administrative and Support Services
# 99999   Professional, Scientific, and Technical Services
#
#                                        clean_description  \
# 0      white horse ceramic singapore lead manufacture...
# 1      wealth solution partner pty ltd independent fi...
# 2      pmg general solutions inc environmental remedi...
# 3      tmp capital pllc consult company know franklin...
# 4      genertek power limit privatelyowned uk investm...
# ...                                                  ...
# 99995  karma hardware manufacturer base kothariya raj...
# 99996  rainbow paper australianowned brand specialize...
# 99997  blue support service company offer flexible in...
# 99998  digital citizen new york citybase digital prod...
# 99999  wendy hilliard gymnastics foundation nonprofit...
#
#                                       description_vector
# 0      white horse ceramic singapore lead manufacture...
# 1      wealth solution partner pty ltd independent fi...
# 2      pmg general solutions inc environmental remedi...
# 3      tmp capital pllc consult company know franklin...
# 4      genertek power limit privatelyowned uk investm...
# ...                                                  ...
# 99995  karma hardware manufacturer base kothariya raj...
# 99996  rainbow paper australianowned brand specialize...
# 99997  blue support service company offer flexible in...
# 99998  digital citizen new york citybase digital prod...
# 99999  wendy hilliard gymnastics foundation nonprofit...
#
# [100000 rows x 9 columns]

# %%
dataset = pd.read_csv("data/tournament_hints_data.csv")
dataset
# Out:
#                    commercial_name  \
# 0                      White Horse
# 1         Wealth Solution Partners
# 2                              PMG
# 3                 TMP Capital PLLC
# 4                   Genertek Power
# ...                            ...
# 626241  Global Golf Tech Solutions
# 626242                       Renko
# 626243                     Norstal
# 626244                    Acoustic
# 626245      PAPER MACHINE CLOTHING
#
#                                             business_tags  \
# 0       Tile Manufacturing | European Aesthetics Ceram...
# 1       Super and SMSF Services | Financial Planning a...
# 2       Fire and Water Cleanup Services | Mold Remedia...
# 3       Licensed in AL & FL | 203K Loans | 15-year Fix...
# 4       Industrial and Commercial Energy Storage | Ass...
# ...                                                   ...
# 626241  Manufacturing | Golf Academy | G Launch Monito...
# 626242  Latest Processing Technologies | E Gaskets for...
# 626243  Residential Buildings | Custom Project Service...
# 626244  Wood-based Acoustic Products Manufacturer | De...
# 626245  Detailed Machine Studies and Analytics | Scree...
#
#                                         short_description  \
# 0       White Horse is highly regarded as a tile trail...
# 1       WSP, Wealth Solution Partners, Financial Plann...
# 2       PMG General Solutions Inc. is an environmental...
# 3       TMP Capital PLLC Consulting Company Franklin M...
# 4       Genertek Power Ltd a UK electricity systems & ...
# ...                                                   ...
# 626241  The best personal golf launch monitor screen p...
# 626242  EPDM Rubber products from Renko can be found o...
# 626243  Norstal produces a broad range of steel struct...
# 626244  We are designed and manufactured in UAE, Acous...
# 626245  With Huatao innovative product portfolio of pa...
#
#                                               description  \
# 0       White Horse Ceramic Singapore is a leading man...
# 1       Wealth Solution Partners Pty Ltd is an indepen...
# 2       PMG General Solutions Inc. is an environmental...
# 3       TMP Capital PLLC Consulting Company, also know...
# 4       Genertek Power Limited is a privately-owned UK...
# ...                                                   ...
# 626241  Global Golf Tech Solutions is a company that s...
# 626242  RENKO is a company that has been producing hig...
# 626243  Norstal is a steel structure producer that spe...
# 626244  Acoustic.ae is a member of a UAE-based group o...
# 626245  Huatao Group, also known as Huatao Group, is a...
#
#                              main_business_category
# 0                                        Tile Store
# 1       Investment Consultants & Financial Advisors
# 2             Damage Restoration & Mold Remediation
# 3                                  Mortgage Brokers
# 4                        Renewable energy companies
# ...                                             ...
# 626241                 Golf Courses & Country Clubs
# 626242                   Fabricated Rubber Products
# 626243                   Metal Fabrication Services
# 626244              Building Material Manufacturers
# 626245                   Paper & Cardboard Products
#
# [626246 rows x 5 columns]

# %%
test_df = pd.read_csv("data/data.csv")

# %%
# Vectorize and calculate cosine similarity
vectorizer = TfidfVectorizer()
all_keywords = list(dataset["commercial_name"].to_list())
vectorizer.fit(all_keywords)
vectors = vectorizer.transform(dataset["commercial_name"])
similarity_matrix = cosine_similarity(vectors)

# Find the best NAICS match for each business label based on highest similarity
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 6
#       4 vectorizer.fit(all_keywords)
#       5 vectors = vectorizer.transform(dataset["commercial_name"])
# ----> 6 similarity_matrix = cosine_similarity(vectors)
#       8 # Find the best NAICS match for each business label based on highest similarity
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\sklearn\metrics\pairwise.py:1665, in cosine_similarity(X, Y, dense_output)
#    1662 else:
#    1663     Y_normalized = normalize(Y, copy=True)
# -> 1665 K = safe_sparse_dot(X_normalized, Y_normalized.T, dense_output=dense_output)
#    1667 return K
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\sklearn\utils\extmath.py:216, in safe_sparse_dot(a, b, dense_output)
#     208     ret = a @ b
#     210 if (
#     211     sparse.issparse(a)
#     212     and sparse.issparse(b)
#     213     and dense_output
#     214     and hasattr(ret, "toarray")
#     215 ):
# --> 216     return ret.toarray()
#     217 return ret
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\scipy\sparse\_compressed.py:1101, in _cs_matrix.toarray(self, order, out)
#    1099 if out is None and order is None:
#    1100     order = self._swap('cf')[0]
# -> 1101 out = self._process_toarray_args(order, out)
#    1102 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1103     raise ValueError('Output array must be C or F contiguous')
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\scipy\sparse\_base.py:1327, in _spbase._process_toarray_args(self, order, out)
#    1325     return out
#    1326 else:
# -> 1327     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 2.85 TiB for an array with shape (626246, 626246) and data type float64

# %%
naics_df["keywords"] = naics_df["clean_description"].apply(
    lambda x: extract_top_keywords([x], 10)[0]
)
dataset["keywords_commercial_name"] = dataset["commercial_name"].apply(
    lambda x: extract_top_keywords([x], 10)[0]
)


# Convert keywords list to single string per description
business_df["keywords_str"] = business_df["keywords"].apply(" ".join)
naics_df["keywords_str"] = naics_df["keywords"].apply(" ".join)

# Vectorize and calculate cosine similarity
vectorizer = TfidfVectorizer()
all_keywords = list(naics_df["keywords_str"]) + list(business_df["keywords_str"])
vectorizer.fit(all_keywords)
naics_vectors = vectorizer.transform(naics_df["keywords_str"])
business_vectors = vectorizer.transform(business_df["keywords_str"])
similarity_matrix = cosine_similarity(business_vectors, naics_vectors)

# Find the best NAICS match for each business label based on highest similarity
match_indices = np.argmax(similarity_matrix, axis=1)
business_df["matched_naics_label"] = naics_df["naics_label"].values[match_indices]
business_df["similarity_score"] = np.max(similarity_matrix, axis=1)

# %%
business_df # n=10
# Out:
#                                     label  \
# 0                 ATVs Dealers & Services
# 1                        Abortion Clinics
# 2       Accounting & Bookkeeping Services
# 3                      Acupuncture clinic
# 4                    Adhesives & Sealants
# ..                                    ...
# 598  Work Clothing & Protection Equipment
# 599                 Writers & Copywriters
# 600                            YMCA Camps
# 601                          Yoga Studios
# 602                                   Zoo
#
#                                            description  \
# 0    Businesses categorized under ATVs Dealers & Se...
# 1    Abortion Clinics provide medical services rela...
# 2    Accounting & Bookkeeping Services encompass a ...
# 3    An Acupuncture clinic is a healthcare facility...
# 4    Adhesives & Sealants encompass a diverse range...
# ..                                                 ...
# 598  Work Clothing & Protection Equipment pertains ...
# 599  Writers & Copywriters are skilled professional...
# 600  YMCA Camps offer structured programs and activ...
# 601  Yoga Studios offer a tranquil space for indivi...
# 602  A Zoo is a facility where a diverse collection...
#
#                                      clean_description  \
# 0    business categorize under atvs dealer service ...
# 1    abortion clinic provide medical service relate...
# 2    accounting bookkeeping service encompass a ran...
# 3    an acupuncture clinic be a healthcare facility...
# 4    adhesives sealant encompass a diverse range of...
# ..                                                 ...
# 598  work clothing protection equipment pertain to ...
# 599  writer copywriter be skilled professional who ...
# 600  ymca camp offer structured program and activit...
# 601  yoga studio offer a tranquil space for individ...
# 602  a zoo be a facility where a diverse collection...
#
#                                               keywords  \
# 0    [rental option, repair, maintenance, use, opti...
# 1    [health service, healthcare, healthcare assist...
# 2    [field, ensure compliance, ensure, encompass r...
# 3    [health quality, health condition, facility sp...
# 4    [encompass diverse, encompass, durable bonding...
# ..                                                 ...
# 598  [clothing protection, ensure, protection equip...
# 599  [engaging, individual, write content, writer, ...
# 600  [education physical, education, involvement, t...
# 601  [instructional, individual skill, individual e...
# 602  [environment mimic, environment, effort resear...
#
#                                           keywords_str  \
# 0    rental option repair maintenance use option ve...
# 1    health service healthcare healthcare assistanc...
# 2    field ensure compliance ensure encompass range...
# 3    health quality health condition facility speci...
# 4    encompass diverse encompass durable bonding du...
# ..                                                 ...
# 598  clothing protection ensure protection equipmen...
# 599  engaging individual write content writer copyw...
# 600  education physical education involvement tempo...
# 601  instructional individual skill individual enga...
# 602  environment mimic environment effort research ...
#
#                                    matched_naics_label  similarity_score
# 0                               Repair and Maintenance          0.269430
# 1                                    Social Assistance          0.234246
# 2     Professional, Scientific, and Technical Services          0.059068
# 3                   Health and Personal Care Retailers          0.201104
# 4                  Merchant Wholesalers, Durable Goods          0.272192
# ..                                                 ...               ...
# 598  Clothing, Clothing Accessories, Shoe, and Jewe...          0.237567
# 599                 Broadcasting and Content Providers          0.134737
# 600                                  Social Assistance          0.126352
# 601                  Monetary Authorities-Central Bank          0.055057
# 602       Justice, Public Order, and Safety Activities          0.183397
#
# [603 rows x 7 columns]

# %%
business_df # n=20
# Out:
#                                     label  \
# 0                 ATVs Dealers & Services
# 1                        Abortion Clinics
# 2       Accounting & Bookkeeping Services
# 3                      Acupuncture clinic
# 4                    Adhesives & Sealants
# ..                                    ...
# 598  Work Clothing & Protection Equipment
# 599                 Writers & Copywriters
# 600                            YMCA Camps
# 601                          Yoga Studios
# 602                                   Zoo
#
#                                            description  \
# 0    Businesses categorized under ATVs Dealers & Se...
# 1    Abortion Clinics provide medical services rela...
# 2    Accounting & Bookkeeping Services encompass a ...
# 3    An Acupuncture clinic is a healthcare facility...
# 4    Adhesives & Sealants encompass a diverse range...
# ..                                                 ...
# 598  Work Clothing & Protection Equipment pertains ...
# 599  Writers & Copywriters are skilled professional...
# 600  YMCA Camps offer structured programs and activ...
# 601  Yoga Studios offer a tranquil space for indivi...
# 602  A Zoo is a facility where a diverse collection...
#
#                                      clean_description  \
# 0    business categorize under atvs dealer service ...
# 1    abortion clinic provide medical service relate...
# 2    accounting bookkeeping service encompass a ran...
# 3    an acupuncture clinic be a healthcare facility...
# 4    adhesives sealant encompass a diverse range of...
# ..                                                 ...
# 598  work clothing protection equipment pertain to ...
# 599  writer copywriter be skilled professional who ...
# 600  ymca camp offer structured program and activit...
# 601  yoga studio offer a tranquil space for individ...
# 602  a zoo be a facility where a diverse collection...
#
#                                               keywords  \
# 0    [establishment, establishment offer, ensure, d...
# 1    [clinical setting, confidential, medical servi...
# 2    [insight help, insight, help business, help, f...
# 3    [management, life, licensed acupuncturist, lic...
# 4    [industrial need, industrial, include wide, in...
# ..                                                 ...
# 598  [garment gear, garment, functionality individu...
# 599  [engage inform, engage, effectively communicat...
# 600  [focus foster, focus, experience supportive, e...
# 601  [nurture environment, exercise supportive, exp...
# 602  [house exhibit, house, habitat animal, habitat...
#
#                                           keywords_str  \
# 0    establishment establishment offer ensure desti...
# 1    clinical setting confidential medical service ...
# 2    insight help insight help business help financ...
# 3    management life licensed acupuncturist license...
# 4    industrial need industrial include wide includ...
# ..                                                 ...
# 598  garment gear garment functionality individual ...
# 599  engage inform engage effectively communicate e...
# 600  focus foster focus experience supportive exper...
# 601  nurture environment exercise supportive expect...
# 602  house exhibit house habitat animal habitat edu...
#
#                                    matched_naics_label  similarity_score
# 0                               Repair and Maintenance          0.201426
# 1                      Ambulatory Health Care Services          0.157904
# 2          Funds, Trusts, and Other Financial Vehicles          0.110031
# 3                      Ambulatory Health Care Services          0.118972
# 4                  Merchant Wholesalers, Durable Goods          0.114499
# ..                                                 ...               ...
# 598  Clothing, Clothing Accessories, Shoe, and Jewe...          0.244370
# 599                              Publishing Industries          0.160105
# 600                                      Accommodation          0.108615
# 601            Nursing and Residential Care Facilities          0.097725
# 602                  Animal Production and Aquaculture          0.194367
#
# [603 rows x 7 columns]

# %%
business_df # n=5
# Out:
#                                     label  \
# 0                 ATVs Dealers & Services
# 1                        Abortion Clinics
# 2       Accounting & Bookkeeping Services
# 3                      Acupuncture clinic
# 4                    Adhesives & Sealants
# ..                                    ...
# 598  Work Clothing & Protection Equipment
# 599                 Writers & Copywriters
# 600                            YMCA Camps
# 601                          Yoga Studios
# 602                                   Zoo
#
#                                            description  \
# 0    Businesses categorized under ATVs Dealers & Se...
# 1    Abortion Clinics provide medical services rela...
# 2    Accounting & Bookkeeping Services encompass a ...
# 3    An Acupuncture clinic is a healthcare facility...
# 4    Adhesives & Sealants encompass a diverse range...
# ..                                                 ...
# 598  Work Clothing & Protection Equipment pertains ...
# 599  Writers & Copywriters are skilled professional...
# 600  YMCA Camps offer structured programs and activ...
# 601  Yoga Studios offer a tranquil space for indivi...
# 602  A Zoo is a facility where a diverse collection...
#
#                                      clean_description  \
# 0    business categorize under atvs dealer service ...
# 1    abortion clinic provide medical service relate...
# 2    accounting bookkeeping service encompass a ran...
# 3    an acupuncture clinic be a healthcare facility...
# 4    adhesives sealant encompass a diverse range of...
# ..                                                 ...
# 598  work clothing protection equipment pertain to ...
# 599  writer copywriter be skilled professional who ...
# 600  ymca camp offer structured program and activit...
# 601  yoga studio offer a tranquil space for individ...
# 602  a zoo be a facility where a diverse collection...
#
#                                               keywords  \
# 0                [vehicle, sale, rental, atv, service]
# 1    [counsel medical, clinic, medical, abortion, s...
# 2    [effectively, field responsible, service, prof...
# 3    [patient, overall, acupuncture clinic, clinic,...
# 4           [product, use, sealant, provide, material]
# ..                                                 ...
# 598          [item, safety, equipment, clothing, work]
# 599  [audience, material, content, writer copywrite...
# 600        [service, development, camp, social, offer]
# 601  [instructional session, yoga studio, physical,...
# 602  [zoo typically, public, conservation, animal, ...
#
#                                           keywords_str  \
# 0                      vehicle sale rental atv service
# 1      counsel medical clinic medical abortion service
# 2    effectively field responsible service professi...
# 3    patient overall acupuncture clinic clinic acup...
# 4                 product use sealant provide material
# ..                                                 ...
# 598                item safety equipment clothing work
# 599  audience material content writer copywriter write
# 600              service development camp social offer
# 601  instructional session yoga studio physical ind...
# 602       zoo typically public conservation animal zoo
#
#                               matched_naics_label  similarity_score
# 0                 Motor Vehicle and Parts Dealers          0.418655
# 1                                  Postal Service          0.060666
# 2                                  Postal Service          0.064200
# 3                                 Crop Production          0.000000
# 4     Furniture and Related Product Manufacturing          0.370511
# ..                                            ...               ...
# 598  Justice, Public Order, and Safety Activities          0.225609
# 599            Broadcasting and Content Providers          0.170063
# 600                             Social Assistance          0.303499
# 601                               Crop Production          0.000000
# 602             Animal Production and Aquaculture          0.244857
#
# [603 rows x 7 columns]

# %%
business_df # n=30
# Out:
#                                     label  \
# 0                 ATVs Dealers & Services
# 1                        Abortion Clinics
# 2       Accounting & Bookkeeping Services
# 3                      Acupuncture clinic
# 4                    Adhesives & Sealants
# ..                                    ...
# 598  Work Clothing & Protection Equipment
# 599                 Writers & Copywriters
# 600                            YMCA Camps
# 601                          Yoga Studios
# 602                                   Zoo
#
#                                            description  \
# 0    Businesses categorized under ATVs Dealers & Se...
# 1    Abortion Clinics provide medical services rela...
# 2    Accounting & Bookkeeping Services encompass a ...
# 3    An Acupuncture clinic is a healthcare facility...
# 4    Adhesives & Sealants encompass a diverse range...
# ..                                                 ...
# 598  Work Clothing & Protection Equipment pertains ...
# 599  Writers & Copywriters are skilled professional...
# 600  YMCA Camps offer structured programs and activ...
# 601  Yoga Studios offer a tranquil space for indivi...
# 602  A Zoo is a facility where a diverse collection...
#
#                                      clean_description  \
# 0    business categorize under atvs dealer service ...
# 1    abortion clinic provide medical service relate...
# 2    accounting bookkeeping service encompass a ran...
# 3    an acupuncture clinic be a healthcare facility...
# 4    adhesives sealant encompass a diverse range of...
# ..                                                 ...
# 598  work clothing protection equipment pertain to ...
# 599  writer copywriter be skilled professional who ...
# 600  ymca camp offer structured program and activit...
# 601  yoga studio offer a tranquil space for individ...
# 602  a zoo be a facility where a diverse collection...
#
#                                               keywords  \
# 0    [industry, include sale, include, guidance atv...
# 1    [visit clinic, medical procedure, abortion cli...
# 2    [aim, activity aim, activity, accurate organiz...
# 3    [acupuncturist utilize, acupuncturist, acupunc...
# 4    [adhesion protection, manufacturing, different...
# ..                                                 ...
# 598  [helmet, hazard promote, hazard, goggle essent...
# 599  [idea, help business, help, greeting card, gre...
# 600  [activity design, cater, ymca, development emp...
# 601  [engage physical, exercise, engage, class, cat...
# 602  [animal house, addition serve, natural habitat...
#
#                                           keywords_str  \
# 0    industry include sale include guidance atv gui...
# 1    visit clinic medical procedure abortion clinic...
# 2    aim activity aim activity accurate organize ac...
# 3    acupuncturist utilize acupuncturist acupunctur...
# 4    adhesion protection manufacturing different su...
# ..                                                 ...
# 598  helmet hazard promote hazard goggle essential ...
# 599  idea help business help greeting card greeting...
# 600  activity design cater ymca development emphasi...
# 601  engage physical exercise engage class cater in...
# 602  animal house addition serve natural habitat di...
#
#                                    matched_naics_label  similarity_score
# 0                               Repair and Maintenance          0.175069
# 1              Nursing and Residential Care Facilities          0.154082
# 2    Computing Infrastructure Providers, Data Proce...          0.127419
# 3              Nursing and Residential Care Facilities          0.090690
# 4        Computer and Electronic Product Manufacturing          0.128232
# ..                                                 ...               ...
# 598  Clothing, Clothing Accessories, Shoe, and Jewe...          0.152324
# 599                              Publishing Industries          0.080139
# 600  Administration of Housing Programs, Urban Plan...          0.082813
# 601                               Educational Services          0.052862
# 602                      Fishing, Hunting and Trapping          0.237148
#
# [603 rows x 7 columns]

# %%
business_df # n=50
# Out:
#                                     label  \
# 0                 ATVs Dealers & Services
# 1                        Abortion Clinics
# 2       Accounting & Bookkeeping Services
# 3                      Acupuncture clinic
# 4                    Adhesives & Sealants
# ..                                    ...
# 598  Work Clothing & Protection Equipment
# 599                 Writers & Copywriters
# 600                            YMCA Camps
# 601                          Yoga Studios
# 602                                   Zoo
#
#                                            description  \
# 0    Businesses categorized under ATVs Dealers & Se...
# 1    Abortion Clinics provide medical services rela...
# 2    Accounting & Bookkeeping Services encompass a ...
# 3    An Acupuncture clinic is a healthcare facility...
# 4    Adhesives & Sealants encompass a diverse range...
# ..                                                 ...
# 598  Work Clothing & Protection Equipment pertains ...
# 599  Writers & Copywriters are skilled professional...
# 600  YMCA Camps offer structured programs and activ...
# 601  Yoga Studios offer a tranquil space for indivi...
# 602  A Zoo is a facility where a diverse collection...
#
#                                      clean_description  \
# 0    business categorize under atvs dealer service ...
# 1    abortion clinic provide medical service relate...
# 2    accounting bookkeeping service encompass a ran...
# 3    an acupuncture clinic be a healthcare facility...
# 4    adhesives sealant encompass a diverse range of...
# ..                                                 ...
# 598  work clothing protection equipment pertain to ...
# 599  writer copywriter be skilled professional who ...
# 600  ymca camp offer structured program and activit...
# 601  yoga studio offer a tranquil space for individ...
# 602  a zoo be a facility where a diverse collection...
#
#                                               keywords  \
# 0    [convenient, categorize atvs, categorize, busi...
# 1    [professional healthcare, provide, provide med...
# 2    [responsible, resource effectively, resource, ...
# 3    [specific point, wellbeing, wellbeing patient,...
# 4    [crucial role, crucial, coating application, c...
# ..                                                 ...
# 598  [category, enhance, encompass range, encompass...
# 599  [card, business organization, business, brand ...
# 600  [recreational, need, temporary, involvement of...
# 601  [spiritual practice, studio, studio offer, sup...
# 602  [observe, observe learn, natural, crucial role...
#
#                                           keywords_str  \
# 0    convenient categorize atvs categorize business...
# 1    professional healthcare provide provide medica...
# 2    responsible resource effectively resource rele...
# 3    specific point wellbeing wellbeing patient ove...
# 4    crucial role crucial coating application coati...
# ..                                                 ...
# 598  category enhance encompass range encompass eff...
# 599  card business organization business brand voic...
# 600  recreational need temporary involvement offer ...
# 601  spiritual practice studio studio offer support...
# 602  observe observe learn natural crucial role cru...
#
#                                    matched_naics_label  similarity_score
# 0                      Motor Vehicle and Parts Dealers          0.137153
# 1                                            Hospitals          0.140610
# 2    Securities, Commodity Contracts, and Other Fin...          0.095743
# 3                      Ambulatory Health Care Services          0.099587
# 4     Administration of Environmental Quality Programs          0.090626
# ..                                                 ...               ...
# 598  Clothing, Clothing Accessories, Shoe, and Jewe...          0.148520
# 599                              Publishing Industries          0.067410
# 600                                      Accommodation          0.200502
# 601                               Educational Services          0.089445
# 602                      Fishing, Hunting and Trapping          0.220756
#
# [603 rows x 7 columns]

# %%
business_df # n=3
# Out:
#                                     label  \
# 0                 ATVs Dealers & Services
# 1                        Abortion Clinics
# 2       Accounting & Bookkeeping Services
# 3                      Acupuncture clinic
# 4                    Adhesives & Sealants
# ..                                    ...
# 598  Work Clothing & Protection Equipment
# 599                 Writers & Copywriters
# 600                            YMCA Camps
# 601                          Yoga Studios
# 602                                   Zoo
#
#                                            description  \
# 0    Businesses categorized under ATVs Dealers & Se...
# 1    Abortion Clinics provide medical services rela...
# 2    Accounting & Bookkeeping Services encompass a ...
# 3    An Acupuncture clinic is a healthcare facility...
# 4    Adhesives & Sealants encompass a diverse range...
# ..                                                 ...
# 598  Work Clothing & Protection Equipment pertains ...
# 599  Writers & Copywriters are skilled professional...
# 600  YMCA Camps offer structured programs and activ...
# 601  Yoga Studios offer a tranquil space for indivi...
# 602  A Zoo is a facility where a diverse collection...
#
#                                      clean_description  \
# 0    business categorize under atvs dealer service ...
# 1    abortion clinic provide medical service relate...
# 2    accounting bookkeeping service encompass a ran...
# 3    an acupuncture clinic be a healthcare facility...
# 4    adhesives sealant encompass a diverse range of...
# ..                                                 ...
# 598  work clothing protection equipment pertain to ...
# 599  writer copywriter be skilled professional who ...
# 600  ymca camp offer structured program and activit...
# 601  yoga studio offer a tranquil space for individ...
# 602  a zoo be a facility where a diverse collection...
#
#                                       keywords  \
# 0                       [rental, atv, service]
# 1                 [medical, abortion, service]
# 2           [service, professional, financial]
# 3    [acupuncture clinic, clinic, acupuncture]
# 4                 [sealant, provide, material]
# ..                                         ...
# 598                [equipment, clothing, work]
# 599        [content, writer copywriter, write]
# 600                      [camp, social, offer]
# 601               [physical, individual, yoga]
# 602                [conservation, animal, zoo]
#
#                               keywords_str  \
# 0                       rental atv service
# 1                 medical abortion service
# 2           service professional financial
# 3    acupuncture clinic clinic acupuncture
# 4                 sealant provide material
# ..                                     ...
# 598                equipment clothing work
# 599        content writer copywriter write
# 600                      camp social offer
# 601               physical individual yoga
# 602                conservation animal zoo
#
#                      matched_naics_label  similarity_score
# 0    Administrative and Support Services          0.133505
# 1    Administrative and Support Services          0.142036
# 2    Administrative and Support Services          0.146114
# 3                        Crop Production          0.000000
# 4      Food Services and Drinking Places          0.309452
# ..                                   ...               ...
# 598          Specialty Trade Contractors          0.402276
# 599   Broadcasting and Content Providers          0.268699
# 600                    Social Assistance          0.204873
# 601                      Crop Production          0.000000
# 602    Animal Production and Aquaculture          0.321730
#
# [603 rows x 7 columns]

# %%
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Load the SBERT model
model = SentenceTransformer("all-MiniLM-L6-v2")


# Function to compute embeddings
def compute_embeddings(texts):
    return model.encode(texts, show_progress_bar=True)


# Compute embeddings for each description
business_embeddings = compute_embeddings(business_df["clean_description"].tolist())
naics_embeddings = compute_embeddings(naics_df["clean_description"].tolist())

# Calculate cosine similarity between embeddings
similarity_matrix = cosine_similarity(business_embeddings, naics_embeddings)

# Find the best match for each business description
match_indices = np.argmax(similarity_matrix, axis=1)
business_df["matched_naics_label"] = naics_df["naics_label"].values[match_indices]
business_df["similarity_score"] = np.max(similarity_matrix, axis=1)

# Display results
print(business_df[["label", "matched_naics_label", "similarity_score"]])
# n=15
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from sentence_transformers import SentenceTransformer
#       2 import numpy as np
#       3 from sklearn.metrics.pairwise import cosine_similarity
#
# File c:\Users\andre\anaconda3\envs\env_money_laundering\lib\site-packages\sentence_transformers\__init__.py:3
#       1 __version__ = "2.7.0"
#       2 __MODEL_HUB_ORGANIZATION__ = "sentence-transformers"
# ----> 3 from .datasets import SentencesDataset, ParallelSentencesDataset
#       4 from .LoggingHandler import LoggingHandler
#       5 from .SentenceTransformer import SentenceTransformer
#
# File c:\Users\andre\anaconda3\envs\env_money_laundering\lib\site-packages\sentence_transformers\datasets\__init__.py:1
# ----> 1 from .DenoisingAutoEncoderDataset import DenoisingAutoEncoderDataset
#       2 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
#       3 from .ParallelSentencesDataset import ParallelSentencesDataset
#
# File c:\Users\andre\anaconda3\envs\env_money_laundering\lib\site-packages\sentence_transformers\datasets\DenoisingAutoEncoderDataset.py:1
# ----> 1 from torch.utils.data import Dataset
#       2 from typing import List
#       3 from ..readers.InputExample import InputExample
#
# ModuleNotFoundError: No module named 'torch.utils'

# %%
import torch

print(torch.__version__)
print(torch.rand(2, 2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 import torch
# ----> 3 print(torch.__version__)
#       4 print(torch.rand(2, 2))
#
# AttributeError: module 'torch' has no attribute '__version__'

# %%
import spac

def remove_mentions_and_hashtags(text):
    text = re.sub(r"@\w+", "", text)
    text = re.sub(r"#\w+", "", text)
    return text


def remove_numbers(text):
    text = re.sub(r"\d+", "", text)
    return text


def remove_punctuation(text):

    translator = str.maketrans("", "", string.punctuation)

    # Remove punctuation using the translation table
    text_without_punct = text.translate(translator)

    return text_without_punct


def remove_stopwords(text):
    filtered_sentence = []
    doc = nlp(text)
    for token in doc:
        if token.is_stop == False:
            filtered_sentence.append(token.text)
    return " ".join(filtered_sentence)
y
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re
import string

nlp = spacy.load("en_core_web_md")


def lemmatize(text):
    doc = nlp(text)
    text = " ".join([token.lemma_ for token in doc])
    return text


def clean_text(text, to_lemmatize: bool = True):
    # Standardize text
    # text = standardize_accented_chars(text)

    # Remove URLs
    text = re.sub(r"http\S+", "", text)

    # Remove mentions and hashtags
    text = remove_mentions_and_hashtags(text)

    # Lowercase
    text = text.lower()

    # Remove punctuation
    text = remove_punctuation(text)

    # Remove numbers
    text = remove_numbers(text)

    # Remove all the special characters
    text = re.sub(r"\W", " ", text)

    # Remove stopwords
    text = remove_stopwords(text)

    # Substituting multiple spaces with single space
    text = re.sub(r"\s+", " ", text, flags=re.I)

    if to_lemmatize:
        text = lemmatize(text)

    return text


business_df["clean_description"] = business_df["description"].apply(
    lambda x: clean_text(x)
)
naics_df["clean_description"] = naics_df["description"].apply(
    lambda x: clean_text(x)
)


def extract_entities(text):
    doc = nlp(text)
    return [ent.text for ent in doc.ents]


naics_df["keywords"] = naics_df["clean_description"].apply(extract_entities)
business_df["keywords"] = business_df["clean_description"].apply(extract_entities)

# Convert keywords list to single string per description
naics_df["keywords_str"] = naics_df["keywords"].apply(" ".join)
business_df["keywords_str"] = business_df["keywords"].apply(" ".join)

# Use TF-IDF to vectorize keywords strings
vectorizer = TfidfVectorizer()
all_keywords = list(naics_df["keywords_str"]) + list(business_df["keywords_str"])
vectorizer.fit(all_keywords)
naics_vectors = vectorizer.transform(naics_df["keywords_str"])
business_vectors = vectorizer.transform(business_df["keywords_str"])

# Calculate cosine similarity
similarity_matrix = cosine_similarity(business_vectors, naics_vectors)

# Find the best NAICS match for each business label based on highest similarity
match_indices = np.argmax(similarity_matrix, axis=1)
business_df["matched_naics_label"] = naics_df["naics_label"].values[
    match_indices
]  # Use values to directly access by position
business_df["similarity_score"] = np.max(similarity_matrix, axis=1)

# %%
business_df
# Out:
#                                     label  \
# 0                 ATVs Dealers & Services
# 1                        Abortion Clinics
# 2       Accounting & Bookkeeping Services
# 3                      Acupuncture clinic
# 4                    Adhesives & Sealants
# ..                                    ...
# 598  Work Clothing & Protection Equipment
# 599                 Writers & Copywriters
# 600                            YMCA Camps
# 601                          Yoga Studios
# 602                                   Zoo
#
#                                            description  \
# 0    Businesses categorized under ATVs Dealers & Se...
# 1    Abortion Clinics provide medical services rela...
# 2    Accounting & Bookkeeping Services encompass a ...
# 3    An Acupuncture clinic is a healthcare facility...
# 4    Adhesives & Sealants encompass a diverse range...
# ..                                                 ...
# 598  Work Clothing & Protection Equipment pertains ...
# 599  Writers & Copywriters are skilled professional...
# 600  YMCA Camps offer structured programs and activ...
# 601  Yoga Studios offer a tranquil space for indivi...
# 602  A Zoo is a facility where a diverse collection...
#
#                                      clean_description  \
# 0    business categorize atv dealer service special...
# 1    abortion clinic provide medical service relate...
# 2    accounting bookkeeping service encompass range...
# 3    acupuncture clinic healthcare facility special...
# 4    adhesives sealant encompass diverse range prod...
# ..                                                 ...
# 598  work clothing protection equipment pertain spe...
# 599  writer copywriter skilled professional special...
# 600  ymca camp offer structured program activity de...
# 601  yoga studio offer tranquil space individual en...
# 602  zoo facility diverse collection wild animal ho...
#
#                                       keywords  \
# 0                                           []
# 1    [abortion clinic provide medical service]
# 2                                           []
# 3                                    [chinese]
# 4                                           []
# ..                                         ...
# 598                                         []
# 599                                         []
# 600                [ymca, wellbee development]
# 601                                         []
# 602                                         []
#
#                                 keywords_str            matched_naics_label  \
# 0                                                           Crop Production
# 1    abortion clinic provide medical service  Personal and Laundry Services
# 2                                                           Crop Production
# 3                                    chinese                Crop Production
# 4                                                           Crop Production
# ..                                       ...                            ...
# 598                                                         Crop Production
# 599                                                         Crop Production
# 600                 ymca wellbee development                Crop Production
# 601                                                         Crop Production
# 602                                                         Crop Production
#
#      similarity_score
# 0            0.000000
# 1            0.272744
# 2            0.000000
# 3            0.000000
# 4            0.000000
# ..                ...
# 598          0.000000
# 599          0.000000
# 600          0.000000
# 601          0.000000
# 602          0.000000
#
# [603 rows x 7 columns]

# %%
# display clean_description of first element
print(business_df["clean_description"].iloc[0])
# Out:
# business categorize atv dealer service specialize sale maintenance rental allterrain vehicle atvs establishment offer range service relate atv include sale new vehicle repair maintenance service rental option recreational use customer expect expert guidance atv selection repair service ensure optimal performance convenient rental option outdoor adventure industry dedicated meeting diverse need atv enthusiast provide onestop destination atvrelate requirement

# %%
def jaccard_similarity(list1, list2):
    intersection = set(list1).intersection(set(list2))
    union = set(list1).union(set(list2))
    return len(intersection) / len(union)


# Compute similarity for each combination of NAICS and business description
import numpy as np

similarity_matrix = np.zeros((len(business_df), len(naics_df)))

for i, business_keywords in enumerate(business_df["keywords"]):
    for j, naics_keywords in enumerate(naics_df["keywords"]):
        similarity_matrix[i, j] = jaccard_similarity(business_keywords, naics_keywords)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[57], line 14
#      12 for i, business_keywords in enumerate(business_df["keywords"]):
#      13     for j, naics_keywords in enumerate(naics_df["keywords"]):
# ---> 14         similarity_matrix[i, j] = jaccard_similarity(business_keywords, naics_keywords)
#
# Cell In[57], line 4, in jaccard_similarity(list1, list2)
#       2 intersection = set(list1).intersection(set(list2))
#       3 union = set(list1).union(set(list2))
# ----> 4 return len(intersection) / len(union)
#
# ZeroDivisionError: division by zero

# %%
match_indices = np.argmax(similarity_matrix, axis=1)
business_df["matched_naics_label"] = naics_df["naics_label"].iloc[match_indices].values
business_df["similarity_score"] = np.max(similarity_matrix, axis=1)

# %%
business_df
# Out:
#                                     label  \
# 0                 ATVs Dealers & Services
# 1                        Abortion Clinics
# 2       Accounting & Bookkeeping Services
# 3                      Acupuncture clinic
# 4                    Adhesives & Sealants
# ..                                    ...
# 598  Work Clothing & Protection Equipment
# 599                 Writers & Copywriters
# 600                            YMCA Camps
# 601                          Yoga Studios
# 602                                   Zoo
#
#                                            description  \
# 0    Businesses categorized under ATVs Dealers & Se...
# 1    Abortion Clinics provide medical services rela...
# 2    Accounting & Bookkeeping Services encompass a ...
# 3    An Acupuncture clinic is a healthcare facility...
# 4    Adhesives & Sealants encompass a diverse range...
# ..                                                 ...
# 598  Work Clothing & Protection Equipment pertains ...
# 599  Writers & Copywriters are skilled professional...
# 600  YMCA Camps offer structured programs and activ...
# 601  Yoga Studios offer a tranquil space for indivi...
# 602  A Zoo is a facility where a diverse collection...
#
#                                      clean_description  \
# 0    business categorize atv dealer service special...
# 1    abortion clinic provide medical service relate...
# 2    accounting bookkeeping service encompass range...
# 3    acupuncture clinic healthcare facility special...
# 4    adhesives sealant encompass diverse range prod...
# ..                                                 ...
# 598  work clothing protection equipment pertain spe...
# 599  writer copywriter skilled professional special...
# 600  ymca camp offer structured program activity de...
# 601  yoga studio offer tranquil space individual en...
# 602  zoo facility diverse collection wild animal ho...
#
#                                       keywords  \
# 0                                           []
# 1    [abortion clinic provide medical service]
# 2                                           []
# 3                                    [chinese]
# 4                                           []
# ..                                         ...
# 598                                         []
# 599                                         []
# 600                [ymca, wellbee development]
# 601                                         []
# 602                                         []
#
#                                 keywords_str            matched_naics_label  \
# 0                                                           Crop Production
# 1    abortion clinic provide medical service  Personal and Laundry Services
# 2                                                           Crop Production
# 3                                    chinese                Crop Production
# 4                                                           Crop Production
# ..                                       ...                            ...
# 598                                                         Crop Production
# 599                                                         Crop Production
# 600                 ymca wellbee development                Crop Production
# 601                                                         Crop Production
# 602                                                         Crop Production
#
#      similarity_score
# 0            0.000000
# 1            0.272744
# 2            0.000000
# 3            0.000000
# 4            0.000000
# ..                ...
# 598          0.000000
# 599          0.000000
# 600          0.000000
# 601          0.000000
# 602          0.000000
#
# [603 rows x 7 columns]
