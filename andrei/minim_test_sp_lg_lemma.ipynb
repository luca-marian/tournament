# %% [markdown]
# #### pip install spacy openpyxl
# #### python -m spacy download en_core_web_lg

# %%
import pandas as pd

# Load your CSV files
categories_df = pd.read_excel("data/business_category_taxonomy.xlsx", engine='openpyxl')
domains_df = pd.read_excel("data/Naics3_taxonomy.xlsx", engine='openpyxl')
business_df = pd.read_csv("data/tournament_hints_data.csv", nrows=100000)

# %%
business_df
# Out:
#                 commercial_name  \
# 0                   White Horse
# 1      Wealth Solution Partners
# 2                           PMG
# 3              TMP Capital PLLC
# 4                Genertek Power
# ...                         ...
# 99995            Karma Hardware
# 99996             Rainbow Paper
# 99997     Blue Support Services
# 99998           Digital Citizen
# 99999            Wendy Hilliard
#
#                                            business_tags  \
# 0      Tile Manufacturing | European Aesthetics Ceram...
# 1      Super and SMSF Services | Financial Planning a...
# 2      Fire and Water Cleanup Services | Mold Remedia...
# 3      Licensed in AL & FL | 203K Loans | 15-year Fix...
# 4      Industrial and Commercial Energy Storage | Ass...
# ...                                                  ...
# 99995  Wholesale | Brass Hook Marble Tower Bolt | Coa...
# 99996  Bulky Newsprint | Parchment Paper & Parchment ...
# 99997  24/7 Facility Management | Building Maintenanc...
# 99998  Bespoke Resourcing Solutions | Cross-platform ...
# 99999  Sports Organization | Competition Teams | Gymn...
#
#                                        short_description  \
# 0      White Horse is highly regarded as a tile trail...
# 1      WSP, Wealth Solution Partners, Financial Plann...
# 2      PMG General Solutions Inc. is an environmental...
# 3      TMP Capital PLLC Consulting Company Franklin M...
# 4      Genertek Power Ltd a UK electricity systems & ...
# ...                                                  ...
# 99995  Karma Hardware - Manufacturer of Door Hinges, ...
# 99996  Rainbow Paper offers a huge selection of art &...
# 99997  Blue Support Services provides a flexible and ...
# 99998  Digital Citizen is a NYC-based digital product...
# 99999  Alexis now studies biology at Hunter College a...
#
#                                              description  \
# 0      White Horse Ceramic Singapore is a leading man...
# 1      Wealth Solution Partners Pty Ltd is an indepen...
# 2      PMG General Solutions Inc. is an environmental...
# 3      TMP Capital PLLC Consulting Company, also know...
# 4      Genertek Power Limited is a privately-owned UK...
# ...                                                  ...
# 99995  Karma Hardware is a manufacturer based in Koth...
# 99996  Rainbow Paper is an Australian-owned brand tha...
# 99997  Blue Support Services is a company that offers...
# 99998  Digital Citizen is a New York City-based digit...
# 99999  The Wendy Hilliard Gymnastics Foundation is a ...
#
#                             main_business_category
# 0                                       Tile Store
# 1      Investment Consultants & Financial Advisors
# 2            Damage Restoration & Mold Remediation
# 3                                 Mortgage Brokers
# 4                       Renewable energy companies
# ...                                            ...
# 99995                              Hardware Stores
# 99996                   Paper & Cardboard Products
# 99997            Security Guards & Patrol Services
# 99998                 Digital & Marketing Agencies
# 99999                                   Gymnastics
#
# [100000 rows x 5 columns]

# %%
import spacy
import string
from sklearn.metrics.pairwise import cosine_similarity
import re

# Load the medium spaCy model
nlp = spacy.load("en_core_web_lg")


def remove_mentions_and_hashtags(text):
    text = re.sub(r"@\w+", "", text)
    text = re.sub(r"#\w+", "", text)
    return text


def remove_numbers(text):
    text = re.sub(r"\d+", "", text)
    return text


def remove_punctuation(text):

    translator = str.maketrans("", "", string.punctuation)

    # Remove punctuation using the translation table
    text_without_punct = text.translate(translator)

    return text_without_punct


def remove_stopwords(text):
    filtered_sentence = []
    doc = nlp(text)
    for token in doc:
        if token.is_stop == False:
            filtered_sentence.append(token.text)
    return " ".join(filtered_sentence)


def lemmatize(text):
    doc = nlp(text)
    text = " ".join([token.lemma_ for token in doc])
    return text


def clean_text(text, to_lemmatize: bool = True):
    # Standardize text
    # text = standardize_accented_chars(text)

    # Remove URLs
    text = re.sub(r"http\S+", "", text)

    # Remove mentions and hashtags
    text = remove_mentions_and_hashtags(text)

    # Lowercase
    text = text.lower()

    # Remove punctuation
    text = remove_punctuation(text)

    # Remove numbers
    text = remove_numbers(text)

    # Remove all the special characters
    text = re.sub(r"\W", " ", text)

    # Remove stopwords
    text = remove_stopwords(text)

    # Substituting multiple spaces with single space
    text = re.sub(r"\s+", " ", text, flags=re.I)

    if to_lemmatize:
        text = lemmatize(text)

    return text


categories_df["clean_description"] = categories_df["description"].apply(
    lambda x: clean_text(x)
)
domains_df["clean_description"] = domains_df["description"].apply(
    lambda x: clean_text(x)
)

categories_df["description_vector"] = categories_df["clean_description"].apply(nlp)
domains_df["description_vector"] = domains_df["clean_description"].apply(nlp)

# %%
categories_df[:1]
# Out:
#                      label                                        description  \
# 0  ATVs Dealers & Services  Businesses categorized under ATVs Dealers & Se...
#
#                                    clean_description  \
# 0  business categorize atvs dealer service specia...
#
#                                   description_vector
# 0  (business, categorize, atvs, dealer, service, ...

# %%
def find_best_match(cat_desc_vec, label_vectors):
    # Calculate similarities and return the index of the highest similarity
    similarities = [
        cat_desc_vec.similarity(label_desc) for label_desc in label_vectors
    ]
    return similarities.index(max(similarities))


# Convert domain vectors to a list for efficiency
label_vectors = domains_df["description_vector"].tolist()

# Find the best match for each category
categories_df["best_match_label_index"] = categories_df["description_vector"].apply(
    lambda x: find_best_match(x, label_vectors)
)

# Map the index to the actual domain name
categories_df["best_match_label"] = categories_df["best_match_label_index"].apply(
    lambda x: domains_df.iloc[x]["naics_label"]
)

# %%
categories_df
# Out:
#                                     label  \
# 0                 ATVs Dealers & Services
# 1                        Abortion Clinics
# 2       Accounting & Bookkeeping Services
# 3                      Acupuncture clinic
# 4                    Adhesives & Sealants
# ..                                    ...
# 598  Work Clothing & Protection Equipment
# 599                 Writers & Copywriters
# 600                            YMCA Camps
# 601                          Yoga Studios
# 602                                   Zoo
#
#                                            description  \
# 0    Businesses categorized under ATVs Dealers & Se...
# 1    Abortion Clinics provide medical services rela...
# 2    Accounting & Bookkeeping Services encompass a ...
# 3    An Acupuncture clinic is a healthcare facility...
# 4    Adhesives & Sealants encompass a diverse range...
# ..                                                 ...
# 598  Work Clothing & Protection Equipment pertains ...
# 599  Writers & Copywriters are skilled professional...
# 600  YMCA Camps offer structured programs and activ...
# 601  Yoga Studios offer a tranquil space for indivi...
# 602  A Zoo is a facility where a diverse collection...
#
#                                      clean_description  \
# 0    business categorize atvs dealer service specia...
# 1    abortion clinic provide medical service relate...
# 2    accounting bookkeeping service encompass range...
# 3    acupuncture clinic healthcare facility special...
# 4    adhesive sealant encompass diverse range produ...
# ..                                                 ...
# 598  work clothing protection equipment pertain spe...
# 599  writer copywriter skilled professional special...
# 600  ymca camp offer structured program activity de...
# 601  yoga studio offer tranquil space individual en...
# 602  zoo facility diverse collection wild animal ho...
#
#                                     description_vector  \
# 0    (business, categorize, atvs, dealer, service, ...
# 1    (abortion, clinic, provide, medical, service, ...
# 2    (accounting, bookkeeping, service, encompass, ...
# 3    (acupuncture, clinic, healthcare, facility, sp...
# 4    (adhesive, sealant, encompass, diverse, range,...
# ..                                                 ...
# 598  (work, clothing, protection, equipment, pertai...
# 599  (writer, copywriter, skilled, professional, sp...
# 600  (ymca, camp, offer, structured, program, activ...
# 601  (yoga, studio, offer, tranquil, space, individ...
# 602  (zoo, facility, diverse, collection, wild, ani...
#
#      best_match_label_index                                   best_match_label
# 0                        68                        Rental and Leasing Services
# 1                        76                                          Hospitals
# 2                        72                Administrative and Support Services
# 3                        75                    Ambulatory Health Care Services
# 4                        32                        Miscellaneous Manufacturing
# ..                      ...                                                ...
# 598                      84                             Repair and Maintenance
# 599                      57                              Publishing Industries
# 600                      85                      Personal and Laundry Services
# 601                      79  Performing Arts, Spectator Sports, and Related...
# 602                       1                  Animal Production and Aquaculture
#
# [603 rows x 6 columns]

# %%
business_df[:5]
# Out:
#             commercial_name  \
# 0               White Horse
# 1  Wealth Solution Partners
# 2                       PMG
# 3          TMP Capital PLLC
# 4            Genertek Power
#
#                                        business_tags  \
# 0  Tile Manufacturing | European Aesthetics Ceram...
# 1  Super and SMSF Services | Financial Planning a...
# 2  Fire and Water Cleanup Services | Mold Remedia...
# 3  Licensed in AL & FL | 203K Loans | 15-year Fix...
# 4  Industrial and Commercial Energy Storage | Ass...
#
#                                    short_description  \
# 0  White Horse is highly regarded as a tile trail...
# 1  WSP, Wealth Solution Partners, Financial Plann...
# 2  PMG General Solutions Inc. is an environmental...
# 3  TMP Capital PLLC Consulting Company Franklin M...
# 4  Genertek Power Ltd a UK electricity systems & ...
#
#                                          description  \
# 0  White Horse Ceramic Singapore is a leading man...
# 1  Wealth Solution Partners Pty Ltd is an indepen...
# 2  PMG General Solutions Inc. is an environmental...
# 3  TMP Capital PLLC Consulting Company, also know...
# 4  Genertek Power Limited is a privately-owned UK...
#
#                         main_business_category
# 0                                   Tile Store
# 1  Investment Consultants & Financial Advisors
# 2        Damage Restoration & Mold Remediation
# 3                             Mortgage Brokers
# 4                   Renewable energy companies

# %%
final_data = pd.merge(business_df, categories_df[['label','best_match_label_index','best_match_label']], left_on="main_business_category",right_on="label")
final_data.drop(columns=['label'], inplace=True)

# %%
final_data
# Out:
#                 commercial_name  \
# 0                   White Horse
# 1      Wealth Solution Partners
# 2                           PMG
# 3              TMP Capital PLLC
# 4                Genertek Power
# ...                         ...
# 99995            Karma Hardware
# 99996             Rainbow Paper
# 99997     Blue Support Services
# 99998           Digital Citizen
# 99999            Wendy Hilliard
#
#                                            business_tags  \
# 0      Tile Manufacturing | European Aesthetics Ceram...
# 1      Super and SMSF Services | Financial Planning a...
# 2      Fire and Water Cleanup Services | Mold Remedia...
# 3      Licensed in AL & FL | 203K Loans | 15-year Fix...
# 4      Industrial and Commercial Energy Storage | Ass...
# ...                                                  ...
# 99995  Wholesale | Brass Hook Marble Tower Bolt | Coa...
# 99996  Bulky Newsprint | Parchment Paper & Parchment ...
# 99997  24/7 Facility Management | Building Maintenanc...
# 99998  Bespoke Resourcing Solutions | Cross-platform ...
# 99999  Sports Organization | Competition Teams | Gymn...
#
#                                        short_description  \
# 0      White Horse is highly regarded as a tile trail...
# 1      WSP, Wealth Solution Partners, Financial Plann...
# 2      PMG General Solutions Inc. is an environmental...
# 3      TMP Capital PLLC Consulting Company Franklin M...
# 4      Genertek Power Ltd a UK electricity systems & ...
# ...                                                  ...
# 99995  Karma Hardware - Manufacturer of Door Hinges, ...
# 99996  Rainbow Paper offers a huge selection of art &...
# 99997  Blue Support Services provides a flexible and ...
# 99998  Digital Citizen is a NYC-based digital product...
# 99999  Alexis now studies biology at Hunter College a...
#
#                                              description  \
# 0      White Horse Ceramic Singapore is a leading man...
# 1      Wealth Solution Partners Pty Ltd is an indepen...
# 2      PMG General Solutions Inc. is an environmental...
# 3      TMP Capital PLLC Consulting Company, also know...
# 4      Genertek Power Limited is a privately-owned UK...
# ...                                                  ...
# 99995  Karma Hardware is a manufacturer based in Koth...
# 99996  Rainbow Paper is an Australian-owned brand tha...
# 99997  Blue Support Services is a company that offers...
# 99998  Digital Citizen is a New York City-based digit...
# 99999  The Wendy Hilliard Gymnastics Foundation is a ...
#
#                             main_business_category  best_match_label_index  \
# 0                                       Tile Store                      31
# 1      Investment Consultants & Financial Advisors                      64
# 2            Damage Restoration & Mold Remediation                      84
# 3                                 Mortgage Brokers                      64
# 4                       Renewable energy companies                       8
# ...                                            ...                     ...
# 99995                              Hardware Stores                      37
# 99996                   Paper & Cardboard Products                      20
# 99997            Security Guards & Patrol Services                      64
# 99998                 Digital & Marketing Agencies                      72
# 99999                                   Gymnastics                      70
#
#                                         best_match_label
# 0            Furniture and Related Product Manufacturing
# 1      Securities, Commodity Contracts, and Other Fin...
# 2                                 Repair and Maintenance
# 3      Securities, Commodity Contracts, and Other Fin...
# 4                                              Utilities
# ...                                                  ...
# 99995  Building Material and Garden Equipment and Sup...
# 99996            Printing and Related Support Activities
# 99997  Securities, Commodity Contracts, and Other Fin...
# 99998                Administrative and Support Services
# 99999   Professional, Scientific, and Technical Services
#
# [100000 rows x 7 columns]

# %%
final_data.to_csv('labelled_data.csv', index=False)

# %%
final_data[final_data['main_business_category'] == 'Beauty Salons']
# Out:
#                        commercial_name  \
# 243                      CARIDAD VIDRO
# 680    Azalea Beauty Consultancy India
# 1469                  BEAUTIFUL REMEDY
# 1674           Sogno The Salon Company
# 2244                   Eman Beauty Lab
# ...                                ...
# 98062                   Polish Me Pink
# 98882                Laura J. Crawford
# 99500                   The Vanity Co.
# 99618               Yellow Door Studio
# 99833                 Kitchen Nail Bar
#
#                                            business_tags  \
# 243    On-location Services for Private Events | Brid...
# 680    Sourcing and Purchasing Services | Layout Plan...
# 1469   Waxing Services | Permanent Cosmetics | Facial...
# 1674   Personal Care Services | Hair Coloring Service...
# 2244   Beauty Treatments | Beauty Services | Retail |...
# ...                                                  ...
# 98062                    Beauty & Care | Beauty Services
# 98882  Electrolysis Services | Brazilian Waxing | Hai...
# 99500  Personal Care Services | Microblading Services...
# 99618  Acupuncture | Massage Services | Reiki Service...
# 99833  Spa Treatments | Acrylic Nail | Dipping Treatm...
#
#                                        short_description  \
# 243    Welcome to CARIDAD VIDRO SHOP, wedding favors ...
# 680    Initial and ongoing training and support for S...
# 1469   BEAUTIFUL REMEDY is a beauty salon based in Ka...
# 1674   Sogno The Salon Company is a beauty salon base...
# 2244   Welcome to Eman Beauty Lab, our Nail Salon in ...
# ...                                                  ...
# 98062  Introducing Polish Me Pink, your ultimate solu...
# 98882  Laura J. Crawford - Hair Removal, Brazilian Wa...
# 99500  The Vanity Co. is hair salon that been a stapl...
# 99618  Yellow Door Studio is a fully licensed, artful...
# 99833  Kitchen Nail Bar, Best Nail Salon in San Jose,...
#
#                                              description  \
# 243    Caridad VIDRO is a professional hair and makeu...
# 680    Azalea Beauty Consultancy India is a company t...
# 1469   Beautiful Remedy LLC is a beauty company that ...
# 1674   Sogno The Salon Company is a beauty salon loca...
# 2244   Eman Beauty Lab is a nail salon located in Asc...
# ...                                                  ...
# 98062  Polish Me Pink is a company that offers a cura...
# 98882  Laura J. Crawford is a hair removal studio loc...
# 99500  The Vanity Co. Salon & Esthetics is a hair sal...
# 99618  Yellow Door Studio is a fully licensed, artful...
# 99833  Kitchen Nail Bar is a nail salon located in Sa...
#
#       main_business_category  best_match_label_index  \
# 243            Beauty Salons                      41
# 680            Beauty Salons                      41
# 1469           Beauty Salons                      41
# 1674           Beauty Salons                      41
# 2244           Beauty Salons                      41
# ...                      ...                     ...
# 98062          Beauty Salons                      41
# 98882          Beauty Salons                      41
# 99500          Beauty Salons                      41
# 99618          Beauty Salons                      41
# 99833          Beauty Salons                      41
#
#                          best_match_label
# 243    Health and Personal Care Retailers
# 680    Health and Personal Care Retailers
# 1469   Health and Personal Care Retailers
# 1674   Health and Personal Care Retailers
# 2244   Health and Personal Care Retailers
# ...                                   ...
# 98062  Health and Personal Care Retailers
# 98882  Health and Personal Care Retailers
# 99500  Health and Personal Care Retailers
# 99618  Health and Personal Care Retailers
# 99833  Health and Personal Care Retailers
#
# [283 rows x 7 columns]

# %%
description = "NU U 2 Hair & Beauty is a professional hair and beauty salon located in Milton Regis High Street, Sittingbourne. They offer a variety of hair and body treatments, including hair cutting and styling, as well as other beauty treatments such as waxing, eye treatments, facials, massage, body treatments and permanent make-up."

# %%
final_data["clean_description"] = final_data["description"].apply(
    lambda x: clean_text(x)
)

final_data["description_vector"] = final_data["clean_description"].apply(nlp)

# %%
final_data
# Out:
#                 commercial_name  \
# 0                   White Horse
# 1      Wealth Solution Partners
# 2                           PMG
# 3              TMP Capital PLLC
# 4                Genertek Power
# ...                         ...
# 99995            Karma Hardware
# 99996             Rainbow Paper
# 99997     Blue Support Services
# 99998           Digital Citizen
# 99999            Wendy Hilliard
#
#                                            business_tags  \
# 0      Tile Manufacturing | European Aesthetics Ceram...
# 1      Super and SMSF Services | Financial Planning a...
# 2      Fire and Water Cleanup Services | Mold Remedia...
# 3      Licensed in AL & FL | 203K Loans | 15-year Fix...
# 4      Industrial and Commercial Energy Storage | Ass...
# ...                                                  ...
# 99995  Wholesale | Brass Hook Marble Tower Bolt | Coa...
# 99996  Bulky Newsprint | Parchment Paper & Parchment ...
# 99997  24/7 Facility Management | Building Maintenanc...
# 99998  Bespoke Resourcing Solutions | Cross-platform ...
# 99999  Sports Organization | Competition Teams | Gymn...
#
#                                        short_description  \
# 0      White Horse is highly regarded as a tile trail...
# 1      WSP, Wealth Solution Partners, Financial Plann...
# 2      PMG General Solutions Inc. is an environmental...
# 3      TMP Capital PLLC Consulting Company Franklin M...
# 4      Genertek Power Ltd a UK electricity systems & ...
# ...                                                  ...
# 99995  Karma Hardware - Manufacturer of Door Hinges, ...
# 99996  Rainbow Paper offers a huge selection of art &...
# 99997  Blue Support Services provides a flexible and ...
# 99998  Digital Citizen is a NYC-based digital product...
# 99999  Alexis now studies biology at Hunter College a...
#
#                                              description  \
# 0      White Horse Ceramic Singapore is a leading man...
# 1      Wealth Solution Partners Pty Ltd is an indepen...
# 2      PMG General Solutions Inc. is an environmental...
# 3      TMP Capital PLLC Consulting Company, also know...
# 4      Genertek Power Limited is a privately-owned UK...
# ...                                                  ...
# 99995  Karma Hardware is a manufacturer based in Koth...
# 99996  Rainbow Paper is an Australian-owned brand tha...
# 99997  Blue Support Services is a company that offers...
# 99998  Digital Citizen is a New York City-based digit...
# 99999  The Wendy Hilliard Gymnastics Foundation is a ...
#
#                             main_business_category  best_match_label_index  \
# 0                                       Tile Store                      31
# 1      Investment Consultants & Financial Advisors                      64
# 2            Damage Restoration & Mold Remediation                      84
# 3                                 Mortgage Brokers                      64
# 4                       Renewable energy companies                       8
# ...                                            ...                     ...
# 99995                              Hardware Stores                      37
# 99996                   Paper & Cardboard Products                      20
# 99997            Security Guards & Patrol Services                      64
# 99998                 Digital & Marketing Agencies                      72
# 99999                                   Gymnastics                      70
#
#                                         best_match_label  \
# 0            Furniture and Related Product Manufacturing
# 1      Securities, Commodity Contracts, and Other Fin...
# 2                                 Repair and Maintenance
# 3      Securities, Commodity Contracts, and Other Fin...
# 4                                              Utilities
# ...                                                  ...
# 99995  Building Material and Garden Equipment and Sup...
# 99996            Printing and Related Support Activities
# 99997  Securities, Commodity Contracts, and Other Fin...
# 99998                Administrative and Support Services
# 99999   Professional, Scientific, and Technical Services
#
#                                        clean_description  \
# 0      white horse ceramic singapore lead manufacture...
# 1      wealth solution partner pty ltd independent fi...
# 2      pmg general solutions inc environmental remedi...
# 3      tmp capital pllc consult company know franklin...
# 4      genertek power limit privatelyowned uk investm...
# ...                                                  ...
# 99995  karma hardware manufacturer base kothariya raj...
# 99996  rainbow paper australianowned brand specialize...
# 99997  blue support service company offer flexible in...
# 99998  digital citizen new york citybase digital prod...
# 99999  wendy hilliard gymnastics foundation nonprofit...
#
#                                       description_vector
# 0      (white, horse, ceramic, singapore, lead, manuf...
# 1      (wealth, solution, partner, pty, ltd, independ...
# 2      (pmg, general, solutions, inc, environmental, ...
# 3      (tmp, capital, pllc, consult, company, know, f...
# 4      (genertek, power, limit, privatelyowned, uk, i...
# ...                                                  ...
# 99995  (karma, hardware, manufacturer, base, kothariy...
# 99996  (rainbow, paper, australianowned, brand, speci...
# 99997  (blue, support, service, company, offer, flexi...
# 99998  (digital, citizen, new, york, citybase, digita...
# 99999  (wendy, hilliard, gymnastics, foundation, nonp...
#
# [100000 rows x 9 columns]

# %%
row_index = 5  # Replace with the desired index
specific_row = final_data.loc[row_index]
print(specific_row)
# Out:
# commercial_name                                             HQ Machine Tech
# business_tags             Nickel Alloy Machining | ISO 9001 Certificatio...
# short_description         HQ Machine Tech LLC is closely affiliated with...
# description               HQ Machine Tech, LLC is a company that special...
# main_business_category                         Machinery parts manufacturer
# best_match_label_index                                                   27
# best_match_label                                    Machinery Manufacturing
# clean_description         hq machine tech llc company specialize provide...
# description_vector        (hq, machine, tech, llc, company, specialize, ...
# Name: 5, dtype: object

# %%
final_data.loc[find_best_match(nlp(description),final_data["description_vector"].tolist())]
# Out:
# commercial_name                                                       Mejes
# business_tags             Beautification Products | Eye Masks | Portable...
# short_description         In 1997, Lina Mejes founded the Mejes high-tec...
# description               Mejes Beauté Sciences R & D is a French compan...
# main_business_category                                     Cosmetics Stores
# best_match_label_index                                                   34
# best_match_label                     Merchant Wholesalers, Nondurable Goods
# clean_description         mejes beauté sciences r d french company found...
# description_vector        (mejes, beauté, sciences, r, d, french, compan...
# Name: 27283, dtype: object

# %%
final_data.to_csv('./data/clean_description.csv', index=False)

# %%
description = "Nirmiti Advertising is an authorized agency that specializes in audio and video production for television and radio commercials, event management, and media planning. They are also authorized for various TV channels and radio stations and work in multiple languages such as Marathi, Hindi, English, Gujarati, and Kannada. Their services include event coverage, film production, TV serials, and hoardings. The company is known for their expertise in audio, video, and film production and event management."

final_data.loc[find_best_match(nlp(description),final_data["description_vector"].tolist())]
# Out:
# commercial_name                                          Peekaboo Animation
# business_tags             New Media Production | TV Rights Management | ...
# short_description         Peekaboo Animation produces and distributes ch...
# description               Peekaboo Animation is a studio founded in 2015...
# main_business_category                        Radio & Television Production
# best_match_label_index                                                   58
# best_match_label                         Broadcasting and Content Providers
# clean_description         peekaboo animation studio found specialize dev...
# description_vector        (peekaboo, animation, studio, found, specializ...
# Name: 31705, dtype: object

# %%
# get just an item from the final_data list on column 'description_vector'

important_words = [token.text for token in final_data['description_vector'][0] if token.pos_ in ['NOUN', 'ADJ', 'VERB']]
important_words
# Out:
# ['white',
#  'lead',
#  'manufacturer',
#  'highquality',
#  'ceramic',
#  'offer',
#  'wide',
#  'range',
#  'ceramic',
#  'product',
#  'residential',
#  'commercial',
#  'space',
#  'establish',
#  'company',
#  'know',
#  'commitment',
#  'quality',
#  'innovation',
#  'artistry',
#  'skilled',
#  'artisan',
#  'craft',
#  'piece',
#  'ceramic',
#  'create',
#  'beautiful',
#  'functional',
#  'product',
#  'stand',
#  'test',
#  'time',
#  'global',
#  'presence',
#  'country',
#  'white',
#  'horse',
#  'ceramic',
#  'synonymous',
#  'style',
#  'durability',
#  'unmatched',
#  'craftsmanship',
#  'offer',
#  'variety',
#  'tile',
#  'include',
#  'ceramic',
#  'tile',
#  'stone',
#  'tile',
#  'company',
#  'commit',
#  'sustainability',
#  'offer',
#  'green',
#  'label',
#  'certify',
#  'tile',
#  'meet',
#  'environmental',
#  'performance',
#  'health',
#  'parameter']

# %%
len(final_data['description_vector'][0])
# Out:
# 73

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

def extract_keywords_tfidf(documents, max_features=20):
    vectorizer = TfidfVectorizer(stop_words="english", max_features=max_features)
    tfidf_matrix = vectorizer.fit_transform(documents)
    feature_names = vectorizer.get_feature_names_out()
    # Create a dictionary to store keywords by document
    keywords = {i: [] for i in range(tfidf_matrix.shape[0])}
    for i, j in zip(*tfidf_matrix.nonzero()):
        keywords[i].append(feature_names[j])
    return keywords


# Apply keyword extraction
# documents = final_data["description"].tolist()
# keywords = extract_keywords_tfidf(documents)


# Function to filter keywords by POS tags and recompute vectors
def filter_keywords_recompute_vector(keywords):
    filtered_vectors = []
    for doc_keywords in keywords.values():
        doc = nlp(" ".join(doc_keywords))
        filtered_text = " ".join(
            [token.text for token in doc if token.pos_ in ["NOUN", "ADJ", "VERB"]]
        )
        filtered_vector = nlp(filtered_text).vector
        filtered_vectors.append(filtered_vector)
    return np.array(filtered_vectors)


# Recompute vectors with filtered keywords
filtered_vectors = filter_keywords_recompute_vector(final_data["description_vector"].to_list())

# Assign the new vectors to the dataframe
final_data["keywords"] = list(filtered_vectors)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 34
#      30     return np.array(filtered_vectors)
#      33 # Recompute vectors with filtered keywords
# ---> 34 filtered_vectors = filter_keywords_recompute_vector(final_data["description_vector"].to_list())
#      36 # Assign the new vectors to the dataframe
#      37 final_data["keywords"] = list(filtered_vectors)
#
# Cell In[50], line 23, in filter_keywords_recompute_vector(keywords)
#      21 def filter_keywords_recompute_vector(keywords):
#      22     filtered_vectors = []
# ---> 23     for doc_keywords in keywords.values():
#      24         doc = nlp(" ".join(doc_keywords))
#      25         filtered_text = " ".join(
#      26             [token.text for token in doc if token.pos_ in ["NOUN", "ADJ", "VERB"]]
#      27         )
#
# AttributeError: 'list' object has no attribute 'values'

# %%
import pandas as pd

# Load the datasets
test_df = pd.read_csv("data/data.csv")
dataset = pd.read_csv("data/tournament_hints_data.csv")

# %%
from fuzzywuzzy import process


# Function to find best match for each item in round_1
def find_best_matches(row, choices):
    # This returns the best match, its score, and the index
    best_match = process.extractOne(row, choices)
    return best_match


# Apply the function to each element in the round_1 column
test_df["best_match"] = test_df["round_1"].apply(
    find_best_matches, choices=dataset["commercial_name"].tolist()
)

# Split the tuple of best match into separate columns if needed
test_df[["match_name", "match_score", "match_index"]] = pd.DataFrame(
    test_df["best_match"].tolist(), index=False
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 17
#      12 test_df["best_match"] = test_df["round_1"].apply(
#      13     find_best_matches, choices=dataset["commercial_name"].tolist()
#      14 )
#      16 # Split the tuple of best match into separate columns if needed
# ---> 17 test_df[["match_name", "match_score", "match_index"]] = pd.DataFrame(
#      18     test_df["best_match"].tolist(), index=test_df.index
#      19 )
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
#    4298 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
#    4301     self._set_item_frame_value(key, value)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\frame.py:4341, in DataFrame._setitem_array(self, key, value)
#    4336 else:
#    4337     # Note: unlike self.iloc[:, indexer] = value, this will
#    4338     #  never try to overwrite values inplace
#    4340     if isinstance(value, DataFrame):
# -> 4341         check_key_length(self.columns, key, value)
#    4342         for k1, k2 in zip(key, value.columns):
#    4343             self[k1] = value[k2]
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\indexers\utils.py:390, in check_key_length(columns, key, value)
#     388 if columns.is_unique:
#     389     if len(value.columns) != len(key):
# --> 390         raise ValueError("Columns must be same length as key")
#     391 else:
#     392     # Missing keys in columns are represented as -1
#     393     if len(columns.get_indexer_non_unique(key)[0]) != len(value.columns):
#
# ValueError: Columns must be same length as key

# %%
test_df
# Out:
#      Unnamed: 0  company_id  \
# 0             0          84
# 1             1         115
# 2             2          50
# 3             3          92
# 4             4          88
# ..          ...         ...
# 101         101          28
# 102         102         116
# 103         103           6
# 104         104          24
# 105         105           5
#
#                                                round_1  \
# 0                                        Advisory Care
# 1                                 PPK Mining Equipment
# 2                               First Tracks Lawn Care
# 3                                New Golden Furnishers
# 4                                    Lilac City Septic
# ..                                                 ...
# 101                                        Purple Pixl
# 102                                     Pasargad Jonub
# 103                            Davis Business Machines
# 104                                   High Desert Tool
# 105  Heart to Heart International is a non-profit o...
#
#                                               answer  \
# 0                621 Ambulatory Health Care Services
# 1                  213 Support Activities for Mining
# 2            561 Administrative and Support Services
# 3    337 Furniture and Related Product Manufacturing
# 4      562 Waste Management and Remediation Services
# ..                                               ...
# 101                       811 Repair and Maintenance
# 102     237 Heavy and Civil Engineering Construction
# 103          423 Merchant Wholesalers, Durable Goods
# 104   326 Plastics and Rubber Products Manufacturing
# 105                            624 Social Assistance
#
#                                                round_2  \
# 0    Hygiene Services | One-on-one Attention and Ca...
# 1    High & Low Seam Drills | Ventilation Solutions...
# 2    Weekly Mowing | Driveway Plowing Services | Mu...
# 3    Staff Task Computer Chairs Supplier | Mesh Bac...
# 4    Clean-Out Installation | Line Replacement Serv...
# ..                                                 ...
# 101  Battery Replacement | Viruses Removal | Front ...
# 102  Infrastructure Project Management | Design and...
# 103  Managed IT Services | Document Scanners | Fax ...
# 104  Aerospace Molds Supplier | Automotive Molds Di...
# 105                             Social Services & NGOs
#
#                                                round_3  \
# 0    Advisory Care is a home health care services p...
# 1    PPK Mining Equipment is the solution partner o...
# 2    First Tracks Lawn Care, LLC prides itself on p...
# 3    New Golden Furnishers Co - Manufacturer of Dou...
# 4    Lilac City Septic services residential & comme...
# ..                                                 ...
# 101  Purple Pixl offers fast & effective repair ser...
# 102  Having a brilliant background and well-trained...
# 103  Since May 13, 1963, Davis Business Machines ha...
# 104  High Desert Tool specializes in large mold man...
# 105                                     Heart to Heart
#
#                                                round_4  \
# 0    Advisory Care Pty Ltd is a company that provid...
# 1    PPK Mining Equipment is a company that special...
# 2    First Tracks Lawn Care, LLC is a lawn care com...
# 3    New Golden Furnishers Co is a furniture manufa...
# 4    Lilac City Septic Services Co is a family-owne...
# ..                                                 ...
# 101  Purple Pixl is a technology and electronics re...
# 102  Pasargad Jonub is a private joint stock compan...
# 103  Davis Business Machines is a company that has ...
# 104  High Desert Tool is a company that specializes...
# 105  Global Health Information Provider | Humanitar...
#
#                                                round_5  \
# 0                                     Home Health Care
# 1                             Mining & Gas Exploration
# 2                          Landscaping & Lawn Services
# 3                                     Office Furniture
# 4                  Garbage Collection & Waste Disposal
# ..                                                 ...
# 101                            Phone Repair & Services
# 102                         Civil Engineering Services
# 103                                    Office Supplies
# 104                         Injection Molding Services
# 105  As a healthcare nonprofit organization, Heart ...
#
#                   best_match
# 0          (ADVISORCARE, 92)
# 1     (Mining Equipment, 95)
# 2                  (TRA, 90)
# 3                (Furni, 90)
# 4                  (TIC, 90)
# ..                       ...
# 101                (PUR, 90)
# 102               (ASAR, 90)
# 103                (ESS, 90)
# 104  (High Desert Tools, 97)
# 105              (Natio, 60)
#
# [106 rows x 9 columns]

# %%
test_df[["match_name", "match_score", "match_index"]] = pd.DataFrame(
    test_df["best_match"].tolist(), index=test_df.index
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 test_df[["match_name", "match_score", "match_index"]] = pd.DataFrame(
#       2     test_df["best_match"].tolist(), index=test_df.index
#       3 )
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
#    4298 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
#    4301     self._set_item_frame_value(key, value)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\frame.py:4341, in DataFrame._setitem_array(self, key, value)
#    4336 else:
#    4337     # Note: unlike self.iloc[:, indexer] = value, this will
#    4338     #  never try to overwrite values inplace
#    4340     if isinstance(value, DataFrame):
# -> 4341         check_key_length(self.columns, key, value)
#    4342         for k1, k2 in zip(key, value.columns):
#    4343             self[k1] = value[k2]
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\indexers\utils.py:390, in check_key_length(columns, key, value)
#     388 if columns.is_unique:
#     389     if len(value.columns) != len(key):
# --> 390         raise ValueError("Columns must be same length as key")
#     391 else:
#     392     # Missing keys in columns are represented as -1
#     393     if len(columns.get_indexer_non_unique(key)[0]) != len(value.columns):
#
# ValueError: Columns must be same length as key

# %%
test_df["best_match"].to_list()
# Out:
# [('ADVISORCARE', 92),
#  ('Mining Equipment', 95),
#  ('TRA', 90),
#  ('Furni', 90),
#  ('TIC', 90),
#  ('TNT Industries', 93),
#  ('ROC', 90),
#  ('Bake Me Away', 92),
#  ('The Law Firm Of Carlton F. Bennett', 86),
#  ('Design', 90),
#  ('AGI', 90),
#  ('ABL', 90),
#  ('BLI', 90),
#  ('Reco', 90),
#  ('Cosmetic Surgery', 95),
#  ('Avi', 90),
#  ('JAB training and consultancy', 90),
#  ('IDS', 90),
#  ('TIC', 90),
#  ('Accurate', 90),
#  ('Sti', 90),
#  ('ICAL', 90),
#  ('Tree Service', 90),
#  ('HEÖ', 90),
#  ('Pediatrics', 90),
#  ('OTS', 90),
#  ('JS INTERNATIONAL', 97),
#  ('Roof', 90),
#  ('Roof', 90),
#  ('SIC', 90),
#  ('Extreme Auto Body', 95),
#  ('Inera', 90),
#  ('ATS', 90),
#  ('Studio D', 100),
#  ('Springfield', 90),
#  ('3 Brothers', 90),
#  ('CYCLE', 90),
#  ("Kim's", 90),
#  ('TRA', 90),
#  ('RTR', 90),
#  ('CTS', 90),
#  ('ECT', 90),
#  ('NER', 90),
#  ('Trifta', 91),
#  ('PING', 90),
#  ('Park-n-Store', 92),
#  ('ISTI', 90),
#  ('ARE', 90),
#  ('BIG DIPPER', 100),
#  ('Fanxi Textile', 90),
#  ('IAM', 90),
#  ('IGAN', 90),
#  ('LAT', 90),
#  ('Tax Service', 90),
#  ('LASE', 90),
#  ('HEÖ', 90),
#  ('Allergy', 90),
#  ('LTI', 90),
#  ('Good Guys Home Inspection', 86),
#  ('Marketing', 95),
#  ('ARE', 90),
#  ('ARX', 90),
#  ('WIS', 90),
#  ('Dietaxion', 90),
#  ('D STAR TRADING COMPANY', 91),
#  ('TEC', 90),
#  ('CHR', 90),
#  ('Iló', 90),
#  ('Janak Global FZC', 90),
#  ('Associate', 90),
#  ('Animal Care', 90),
#  ('NEWA', 90),
#  ('TRA', 90),
#  ('ITT', 90),
#  ('EGA', 90),
#  ('ERS', 90),
#  ('M Financial', 92),
#  ('Design', 90),
#  ("T. L. Faison's Funeral Care", 86),
#  ('BBP', 86),
#  ('ABL', 90),
#  ('IBOOLO', 83),
#  ('ESS', 90),
#  ('NGE', 90),
#  ('STEM', 90),
#  ('Detail Masters', 100),
#  ('Collison-Goll', 80),
#  ('COA', 90),
#  ('LIMA', 90),
#  ('Create', 90),
#  ('Ental', 90),
#  ('IEW', 90),
#  ('Forest Homes', 95),
#  ('Mini', 90),
#  ('ARI', 90),
#  ('AOS Investments', 93),
#  ('Alt', 90),
#  ('OSI', 90),
#  ('Teachers', 90),
#  ('ThunderBolt Towing', 95),
#  ('Convenience Best Shipping Hardware Retail', 86),
#  ('PUR', 90),
#  ('ASAR', 90),
#  ('ESS', 90),
#  ('High Desert Tools', 97),
#  ('Natio', 60)]
