# %% [markdown]
# #### pip install spacy openpyxl
# #### python -m spacy download en_core_web_lg

# %%
import pandas as pd

# Load your CSV files
categories_df = pd.read_excel("data/business_category_taxonomy.xlsx", engine='openpyxl')
domains_df = pd.read_excel("data/Naics3_taxonomy.xlsx", engine='openpyxl')
business_df = pd.read_csv("data/tournament_hints_data.csv", nrows=10000)

# %%
import spacy
import string
from sklearn.metrics.pairwise import cosine_similarity
import re

# Load the medium spaCy model
nlp = spacy.load("en_core_web_md")


def remove_mentions_and_hashtags(text):
    text = re.sub(r"@\w+", "", text)
    text = re.sub(r"#\w+", "", text)
    return text


def remove_numbers(text):
    text = re.sub(r"\d+", "", text)
    return text


def remove_punctuation(text):

    translator = str.maketrans("", "", string.punctuation)

    # Remove punctuation using the translation table
    text_without_punct = text.translate(translator)

    return text_without_punct


def remove_stopwords(text):
    filtered_sentence = []
    doc = nlp(text)
    for token in doc:
        if token.is_stop == False:
            filtered_sentence.append(token.text)
    return " ".join(filtered_sentence)


def lemmatize(text):
    doc = nlp(text)
    text = " ".join([token.lemma_ for token in doc])
    return text


def clean_text(text, to_lemmatize: bool = True):
    # Standardize text
    # text = standardize_accented_chars(text)

    # Remove URLs
    text = re.sub(r"http\S+", "", text)

    # Remove mentions and hashtags
    text = remove_mentions_and_hashtags(text)

    # Lowercase
    text = text.lower()

    # Remove punctuation
    text = remove_punctuation(text)

    # Remove numbers
    text = remove_numbers(text)

    # Remove all the special characters
    text = re.sub(r"\W", " ", text)

    # Remove stopwords
    text = remove_stopwords(text)

    # Substituting multiple spaces with single space
    text = re.sub(r"\s+", " ", text, flags=re.I)

    if to_lemmatize:
        text = lemmatize(text)

    return text


categories_df["clean_description"] = categories_df["description"].apply(
    lambda x: clean_text(x, to_lemmatize=False)
)
domains_df["clean_description"] = domains_df["description"].apply(
    lambda x: clean_text(x, to_lemmatize=False)
)

categories_df["description_vector"] = categories_df["clean_description"].apply(nlp)
domains_df["description_vector"] = domains_df["clean_description"].apply(nlp)

# %%
categories_df
# Out:
#                                     label  \
# 0                 ATVs Dealers & Services
# 1                        Abortion Clinics
# 2       Accounting & Bookkeeping Services
# 3                      Acupuncture clinic
# 4                    Adhesives & Sealants
# ..                                    ...
# 598  Work Clothing & Protection Equipment
# 599                 Writers & Copywriters
# 600                            YMCA Camps
# 601                          Yoga Studios
# 602                                   Zoo
#
#                                            description  \
# 0    Businesses categorized under ATVs Dealers & Se...
# 1    Abortion Clinics provide medical services rela...
# 2    Accounting & Bookkeeping Services encompass a ...
# 3    An Acupuncture clinic is a healthcare facility...
# 4    Adhesives & Sealants encompass a diverse range...
# ..                                                 ...
# 598  Work Clothing & Protection Equipment pertains ...
# 599  Writers & Copywriters are skilled professional...
# 600  YMCA Camps offer structured programs and activ...
# 601  Yoga Studios offer a tranquil space for indivi...
# 602  A Zoo is a facility where a diverse collection...
#
#                                      clean_description  \
# 0    businesses categorized atvs dealers services s...
# 1    abortion clinics provide medical services rela...
# 2    accounting bookkeeping services encompass rang...
# 3    acupuncture clinic healthcare facility special...
# 4    adhesives sealants encompass diverse range pro...
# ..                                                 ...
# 598  work clothing protection equipment pertains sp...
# 599  writers copywriters skilled professionals spec...
# 600  ymca camps offer structured programs activitie...
# 601  yoga studios offer tranquil space individuals ...
# 602  zoo facility diverse collection wild animals h...
#
#                                     description_vector
# 0    (businesses, categorized, atvs, dealers, servi...
# 1    (abortion, clinics, provide, medical, services...
# 2    (accounting, bookkeeping, services, encompass,...
# 3    (acupuncture, clinic, healthcare, facility, sp...
# 4    (adhesives, sealants, encompass, diverse, rang...
# ..                                                 ...
# 598  (work, clothing, protection, equipment, pertai...
# 599  (writers, copywriters, skilled, professionals,...
# 600  (ymca, camps, offer, structured, programs, act...
# 601  (yoga, studios, offer, tranquil, space, indivi...
# 602  (zoo, facility, diverse, collection, wild, ani...
#
# [603 rows x 4 columns]

# %%
def find_best_match(cat_desc_vec, label_vectors):
    # Calculate similarities and return the index of the highest similarity
    similarities = [
        cat_desc_vec.similarity(label_desc) for label_desc in label_vectors
    ]
    return similarities.index(max(similarities))


# Convert domain vectors to a list for efficiency
label_vectors = domains_df["description_vector"].tolist()

# Find the best match for each category
categories_df["best_match_label_index"] = categories_df["description_vector"].apply(
    lambda x: find_best_match(x, label_vectors)
)

# Map the index to the actual domain name
categories_df["best_match_label"] = categories_df["best_match_label_index"].apply(
    lambda x: domains_df.iloc[x]["naics_label"]
)

# %%
categories_df.to_csv("data/categories_with_best_match.csv", index=False)

# %%
business_df[:5]
# Out:
#             commercial_name  \
# 0               White Horse
# 1  Wealth Solution Partners
# 2                       PMG
# 3          TMP Capital PLLC
# 4            Genertek Power
#
#                                        business_tags  \
# 0  Tile Manufacturing | European Aesthetics Ceram...
# 1  Super and SMSF Services | Financial Planning a...
# 2  Fire and Water Cleanup Services | Mold Remedia...
# 3  Licensed in AL & FL | 203K Loans | 15-year Fix...
# 4  Industrial and Commercial Energy Storage | Ass...
#
#                                    short_description  \
# 0  White Horse is highly regarded as a tile trail...
# 1  WSP, Wealth Solution Partners, Financial Plann...
# 2  PMG General Solutions Inc. is an environmental...
# 3  TMP Capital PLLC Consulting Company Franklin M...
# 4  Genertek Power Ltd a UK electricity systems & ...
#
#                                          description  \
# 0  White Horse Ceramic Singapore is a leading man...
# 1  Wealth Solution Partners Pty Ltd is an indepen...
# 2  PMG General Solutions Inc. is an environmental...
# 3  TMP Capital PLLC Consulting Company, also know...
# 4  Genertek Power Limited is a privately-owned UK...
#
#                         main_business_category
# 0                                   Tile Store
# 1  Investment Consultants & Financial Advisors
# 2        Damage Restoration & Mold Remediation
# 3                             Mortgage Brokers
# 4                   Renewable energy companies

# %%
final_data = pd.merge(business_df, categories_df[['label','best_match_label_index','best_match_label']], left_on="main_business_category",right_on="label")
final_data.drop(columns=['label'], inplace=True)

# %%
final_data
# Out:
#                commercial_name  \
# 0                  White Horse
# 1     Wealth Solution Partners
# 2                          PMG
# 3             TMP Capital PLLC
# 4               Genertek Power
# ...                        ...
# 9995               Racing Duel
# 9996           Triton Graphite
# 9997       NW Diamond painting
# 9998                 TMF Tires
# 9999        Neil Bage Kitchens
#
#                                           business_tags  \
# 0     Tile Manufacturing | European Aesthetics Ceram...
# 1     Super and SMSF Services | Financial Planning a...
# 2     Fire and Water Cleanup Services | Mold Remedia...
# 3     Licensed in AL & FL | 203K Loans | 15-year Fix...
# 4     Industrial and Commercial Energy Storage | Ass...
# ...                                                 ...
# 9995  Military Games | Handball Manager | Boxing Due...
# 9996  Graphite Products Manufacturer | Graphite Rods...
# 9997  Sealing Services | Drywall Repair Services | P...
# 9998  Wheel-related Products and Services | Automoti...
# 9999  Furnishings for Offices | Furniture Designing ...
#
#                                       short_description  \
# 0     White Horse is highly regarded as a tile trail...
# 1     WSP, Wealth Solution Partners, Financial Plann...
# 2     PMG General Solutions Inc. is an environmental...
# 3     TMP Capital PLLC Consulting Company Franklin M...
# 4     Genertek Power Ltd a UK electricity systems & ...
# ...                                                 ...
# 9995  Racing Duel is an online racing game where you...
# 9996  Industrial Graphite Products manufacturers - T...
# 9997  In addition to standard interior and exterior ...
# 9998  Trying to find a Tire Dealer and Service Provi...
# 9999  Neil Bage Kitchens & Bedrooms • Beautiful Besp...
#
#                                             description  \
# 0     White Horse Ceramic Singapore is a leading man...
# 1     Wealth Solution Partners Pty Ltd is an indepen...
# 2     PMG General Solutions Inc. is an environmental...
# 3     TMP Capital PLLC Consulting Company, also know...
# 4     Genertek Power Limited is a privately-owned UK...
# ...                                                 ...
# 9995  Racing Duel is an online racing game that allo...
# 9996  Triton Graphite is a well-known manufacturer, ...
# 9997  NW Diamond Painting LLC is a professional pain...
# 9998  TMF Tires Inc is a tire dealer located in Stua...
# 9999  Neil Bage Kitchens & Bedrooms is a company bas...
#
#                            main_business_category  best_match_label_index  \
# 0                                      Tile Store                      31
# 1     Investment Consultants & Financial Advisors                      64
# 2           Damage Restoration & Mold Remediation                      84
# 3                                Mortgage Brokers                      64
# 4                      Renewable energy companies                      22
# ...                                           ...                     ...
# 9995                Race Tracks & Racing Supplies                      81
# 9996                      Minerals, Earths & Ores                      24
# 9997         Painting, Plastering & Wall Covering                      31
# 9998                Breaks, Wheels & Tire Dealers                      36
# 9999                Kitchen Furniture & Equipment                      37
#
#                                        best_match_label
# 0           Furniture and Related Product Manufacturing
# 1     Securities, Commodity Contracts, and Other Fin...
# 2                                Repair and Maintenance
# 3     Securities, Commodity Contracts, and Other Fin...
# 4                                Chemical Manufacturing
# ...                                                 ...
# 9995     Amusement, Gambling, and Recreation Industries
# 9996          Nonmetallic Mineral Product Manufacturing
# 9997        Furniture and Related Product Manufacturing
# 9998                    Motor Vehicle and Parts Dealers
# 9999  Building Material and Garden Equipment and Sup...
#
# [10000 rows x 7 columns]

# %%
final_data.to_csv('labelled_data.csv', index=False)

# %%
final_data[final_data['main_business_category'] == 'Beauty Salons']
# Out:
#                       commercial_name  \
# 243                     CARIDAD VIDRO
# 680   Azalea Beauty Consultancy India
# 1469                 BEAUTIFUL REMEDY
# 1674          Sogno The Salon Company
# 8694          Beauty Salons                      41
# 8874          Beauty Salons                      41
# 9256          Beauty Salons                      41
# 9288          Beauty Salons                      41
# 9746          Beauty Salons                      41
# 9748          Beauty Salons                      41
#
#                         best_match_label
# 243   Health and Personal Care Retailers
# 680   Health and Personal Care Retailers
# 1469  Health and Personal Care Retailers
# 1674  Health and Personal Care Retailers
# 2244  Health and Personal Care Retailers
# 2535  Health and Personal Care Retailers
# 2577  Health and Personal Care Retailers
# 3064  Health and Personal Care Retailers
# 3271  Health and Personal Care Retailers
# 3337  Health and Personal Care Retailers
# 3375  Health and Personal Care Retailers
# 4512  Health and Personal Care Retailers
# 4805  Health and Personal Care Retailers
# 5108  Health and Personal Care Retailers
# 6185  Health and Personal Care Retailers
# 6520  Health and Personal Care Retailers
# 6565  Health and Personal Care Retailers
# 6784  Health and Personal Care Retailers
# 7740  Health and Personal Care Retailers
# 7886  Health and Personal Care Retailers
# 8343  Health and Personal Care Retailers
# 8479  Health and Personal Care Retailers
# 8694  Health and Personal Care Retailers
# 8874  Health and Personal Care Retailers
# 9256  Health and Personal Care Retailers
# 9288  Health and Personal Care Retailers
# 9746  Health and Personal Care Retailers
# 9748  Health and Personal Care Retailers

# %%
description = "NU U 2 Hair & Beauty is a professional hair and beauty salon located in Milton Regis High Street, Sittingbourne. They offer a variety of hair and body treatments, including hair cutting and styling, as well as other beauty treatments such as waxing, eye treatments, facials, massage, body treatments and permanent make-up."

# %%
final_data["clean_description"] = final_data["description"].apply(
    lambda x: clean_text(x)
)

final_data["description_vector"] = final_data["clean_description"].apply(nlp)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 final_data["clean_description"] = final_data["description"].apply(
#       2     lambda x: clean_text(x)
#       3 )
#       5 final_data["description_vector"] = final_data["clean_description"].apply(nlp)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[13], line 2, in <lambda>(x)
#       1 final_data["clean_description"] = final_data["description"].apply(
# ----> 2     lambda x: clean_text(x)
#       3 )
#       5 final_data["description_vector"] = final_data["clean_description"].apply(nlp)
#
# Cell In[3], line 75, in clean_text(text, to_lemmatize)
#      72 text = re.sub(r"\s+", " ", text, flags=re.I)
#      74 if to_lemmatize:
# ---> 75     text = lemmatize(text)
#      77 return text
#
# Cell In[3], line 41, in lemmatize(text)
#      40 def lemmatize(text):
# ---> 41     doc = nlp(text)
#      42     text = " ".join([token.lemma_ for token in doc])
#      43     return text
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\spacy\language.py:1049, in Language.__call__(self, text, disable, component_cfg)
#    1047     error_handler = proc.get_error_handler()
#    1048 try:
# -> 1049     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1050 except KeyError as e:
#    1051     # This typically happens if a component is not initialized
#    1052     raise ValueError(Errors.E109.format(name=name)) from e
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\spacy\pipeline\trainable_pipe.pyx:52, in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\spacy\pipeline\tok2vec.py:126, in Tok2Vec.predict(self, docs)
#     124     width = self.model.get_dim("nO")
#     125     return [self.model.ops.alloc((0, width)) for doc in docs]
# --> 126 tokvecs = self.model.predict(docs)
#     127 return tokvecs
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:334, in Model.predict(self, X)
#     330 def predict(self, X: InT) -> OutT:
#     331     """Call the model's `forward` function with `is_train=False`, and return
#     332     only the output, instead of the `(output, callback)` tuple.
#     333     """
# --> 334     return self._func(self, X, is_train=False)[0]
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\with_array.py:42, in forward(model, Xseq, is_train)
#      40     return model.layers[0](Xseq, is_train)
#      41 else:
# ---> 42     return cast(Tuple[SeqT, Callable], _list_forward(model, Xseq, is_train))
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\with_array.py:77, in _list_forward(model, Xs, is_train)
#      75 lengths = NUMPY_OPS.asarray1i([len(seq) for seq in Xs])
#      76 Xf = layer.ops.flatten(Xs, pad=pad)
# ---> 77 Yf, get_dXf = layer(Xf, is_train)
#      79 def backprop(dYs: ListXd) -> ListXd:
#      80     dYf = layer.ops.flatten(dYs, pad=pad)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\residual.py:41, in forward(model, X, is_train)
#      38     else:
#      39         return d_output + dX
# ---> 41 Y, backprop_layer = model.layers[0](X, is_train)
#      42 if isinstance(X, list):
#      43     return [X[i] + Y[i] for i in range(len(X))], backprop
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
#     [... skipping similar frames: Model.__call__ at line 310 (1 times)]
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\layernorm.py:25, in forward(model, X, is_train)
#      23 def forward(model: Model[InT, InT], X: InT, is_train: bool) -> Tuple[InT, Callable]:
#      24     N, mu, var = _get_moments(model.ops, X)
# ---> 25     Xhat = (X - mu) * var ** (-1.0 / 2.0)
#      26     Y, backprop_rescale = _begin_update_scale_shift(model, Xhat)
#      28     def backprop(dY: InT) -> InT:
#
# KeyboardInterrupt:

# %%
final_data

# %%
import pandas as pd

# Load the datasets
test_df = pd.read_csv("data/data.csv",nrows=105)
dataset = pd.read_csv("data/tournament_hints_data.csv",nrows=10000)

# Drop or fill NaN values

# %%
from fuzzywuzzy import process


# Function to find best match for each item in round_1
def find_best_matches(row, choices):
    print("row: ", row)
    best_match = process.extractOne(row, choices)
    return best_match


# Apply the function to each element in the round_1 column
test_df["best_match"] = test_df["round_1"].apply(
    find_best_matches, choices=dataset["commercial_name"].tolist()
)

# Split the tuple of best match into separate columns if needed
test_df[["match_name", "match_score", "match_index"]] = pd.DataFrame(
    test_df["best_match"].tolist(), index=test_df.index
)
# Out:
# row:  Advisory Care
# row:  PPK Mining Equipment
# row:  First Tracks Lawn Care
# row:  New Golden Furnishers
# row:  Lilac City Septic
# row:  TTT Industries
# row:  Rocks on the River
# row:  Cake Me Away
# row:  Saadzoi Law
# row:  Harlequin Designs
# row:  OIC DEVAGIRI
# row:  Reliable IT School
# row:  Oblique Aqua
# row:  Water N Fire Recovery
# row:  Venus Cosmetic Surgery
# row:  Lavish Looks
# row:  Smart Training and Consultancy
# row:  Kids & Giggles
# row:  Fcoustic
# row:  Accurate Profile Pipe Fabrication
# row:  Dr. Stitch
# row:  Maveric Medical
# row:  Graham Tree Service
# row:  The Spicy Shark
# row:  Pedsplus Pediatrics
# row:  Cahoots
# row:  JPS International
# row:  The Cotswold Roof Company
# row:  The Cotswold Roof Company
# row:  Maggie Music
# row:  Extreme Auto
# row:  Mineral Lake Lodge
# row:  GOODBEATS
# row:  Studio D
# row:  Springfield Painting Services
# row:  3 Brothers Electric
# row:  Valley Cycle Locksmiths
# row:  Skim Steezy
# row:  Central Seafoods
# row:  Avertro
# row:  Hickory Knoll Architects
# row:  Quest Connect
# row:  Flux Solar Energy
# row:  Trita
# row:  Black Diamond Pumping
# row:  Pack N Store
# row:  Kristi Juneau
# row:  Oncall Care Agency
# row:  Big Dipper
# row:  FANXI
# row:  Siam Chuyo
# row:  Birch Michigan
# row:  Garrity Insulation
# row:  Honest tax service
# row:  NYCLaserDentist
# row:  Amin leather
# row:  Asthma and Allergy
# row:  Bluenest Consulting
# row:  Good Sharma Yoga
# row:  SMA Marketing
# row:  Kutztown Area Historical
# row:  Starx Trust
# row:  Swiss Garnier
# row:  XION
# row:  OldeSTAR Trading Company
# row:  GVN Infotech
# row:  INCHR
# row:  Major Family Law
# row:  AK Global
# row:  Cornerstone Global Associates
# row:  Clinton Animal Care Center
# row:  Canford Renewable Energy
# row:  Nob Hill Travel
# row:  Garb Fitti Removal
# row:  Bieganek Insurance
# row:  Infoversal
# row:  MCP Financial
# row:  Innovative Design Concern
# row:  Maggie's Lunchbox
# row:  Bbop
# row:  Capable Couriers
# row:  Boozlo
# row:  Noire Essentials
# row:  Choice Flower Exchange
# row:  All County Wall Systems
# row:  Detail masters
# row:  Gyoll
# row:  Organic Health Coaching
# row:  Climate Tamers
# row:  Create World
# row:  Lucky Duck River Rentals
# row:  Ridgeview Motors
# row:  FOREST VIEW HOMES
# row:  Hickory Hills Condominium
# row:  KaribuTaxi
# row:  AXS Investments
# row:  Pest Control Altona
# row:  Randy Pelosi
# row:  Teachers on Demand
# row:  Thunderbolt Towing Company
# row:  Best Practice Psychotherapy
# row:  Purple Pixl
# row:  Pasargad Jonub
# row:  Davis Business Machines
# row:  High Desert Tool
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 17
#      12 test_df["best_match"] = test_df["round_1"].apply(
#      13     find_best_matches, choices=dataset["commercial_name"].tolist()
#      14 )
#      16 # Split the tuple of best match into separate columns if needed
# ---> 17 test_df[["match_name", "match_score", "match_index"]] = pd.DataFrame(
#      18     test_df["best_match"].tolist(), index=test_df.index
#      19 )
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\frame.py:4299, in DataFrame.__setitem__(self, key, value)
#    4297     self._setitem_frame(key, value)
#    4298 elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4299     self._setitem_array(key, value)
#    4300 elif isinstance(value, DataFrame):
#    4301     self._set_item_frame_value(key, value)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\frame.py:4341, in DataFrame._setitem_array(self, key, value)
#    4336 else:
#    4337     # Note: unlike self.iloc[:, indexer] = value, this will
#    4338     #  never try to overwrite values inplace
#    4340     if isinstance(value, DataFrame):
# -> 4341         check_key_length(self.columns, key, value)
#    4342         for k1, k2 in zip(key, value.columns):
#    4343             self[k1] = value[k2]
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\indexers\utils.py:390, in check_key_length(columns, key, value)
#     388 if columns.is_unique:
#     389     if len(value.columns) != len(key):
# --> 390         raise ValueError("Columns must be same length as key")
#     391 else:
#     392     # Missing keys in columns are represented as -1
#     393     if len(columns.get_indexer_non_unique(key)[0]) != len(value.columns):
#
# ValueError: Columns must be same length as key
