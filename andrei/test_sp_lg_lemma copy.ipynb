# %% [markdown]
# #### pip install spacy openpyxl
# #### python -m spacy download en_core_web_lg

# %%
import pandas as pd

# Load your CSV files
categories_df = pd.read_excel("data/business_category_taxonomy.xlsx", engine='openpyxl')
domains_df = pd.read_excel("data/Naics3_taxonomy.xlsx", engine='openpyxl')
business_df = pd.read_csv("data/tournament_hints_data.csv")

# %%
clean_description_df = pd.read_csv("data/clean_description.csv")

# %%
business_df
# Out:
#                    commercial_name  \
# 0                      White Horse
# 1         Wealth Solution Partners
# 2                              PMG
# 3                 TMP Capital PLLC
# 4                   Genertek Power
# ...                            ...
# 626241  Global Golf Tech Solutions
# 626242                       Renko
# 626243                     Norstal
# 626244                    Acoustic
# 626245      PAPER MACHINE CLOTHING
#
#                                             business_tags  \
# 0       Tile Manufacturing | European Aesthetics Ceram...
# 1       Super and SMSF Services | Financial Planning a...
# 2       Fire and Water Cleanup Services | Mold Remedia...
# 3       Licensed in AL & FL | 203K Loans | 15-year Fix...
# 4       Industrial and Commercial Energy Storage | Ass...
# ...                                                   ...
# 626241  Manufacturing | Golf Academy | G Launch Monito...
# 626242  Latest Processing Technologies | E Gaskets for...
# 626243  Residential Buildings | Custom Project Service...
# 626244  Wood-based Acoustic Products Manufacturer | De...
# 626245  Detailed Machine Studies and Analytics | Scree...
#
#                                         short_description  \
# 0       White Horse is highly regarded as a tile trail...
# 1       WSP, Wealth Solution Partners, Financial Plann...
# 2       PMG General Solutions Inc. is an environmental...
# 3       TMP Capital PLLC Consulting Company Franklin M...
# 4       Genertek Power Ltd a UK electricity systems & ...
# ...                                                   ...
# 626241  The best personal golf launch monitor screen p...
# 626242  EPDM Rubber products from Renko can be found o...
# 626243  Norstal produces a broad range of steel struct...
# 626244  We are designed and manufactured in UAE, Acous...
# 626245  With Huatao innovative product portfolio of pa...
#
#                                               description  \
# 0       White Horse Ceramic Singapore is a leading man...
# 1       Wealth Solution Partners Pty Ltd is an indepen...
# 2       PMG General Solutions Inc. is an environmental...
# 3       TMP Capital PLLC Consulting Company, also know...
# 4       Genertek Power Limited is a privately-owned UK...
# ...                                                   ...
# 626241  Global Golf Tech Solutions is a company that s...
# 626242  RENKO is a company that has been producing hig...
# 626243  Norstal is a steel structure producer that spe...
# 626244  Acoustic.ae is a member of a UAE-based group o...
# 626245  Huatao Group, also known as Huatao Group, is a...
#
#                              main_business_category
# 0                                        Tile Store
# 1       Investment Consultants & Financial Advisors
# 2             Damage Restoration & Mold Remediation
# 3                                  Mortgage Brokers
# 4                        Renewable energy companies
# ...                                             ...
# 626241                 Golf Courses & Country Clubs
# 626242                   Fabricated Rubber Products
# 626243                   Metal Fabrication Services
# 626244              Building Material Manufacturers
# 626245                   Paper & Cardboard Products
#
# [626246 rows x 5 columns]

# %%
import spacy
import string
from sklearn.metrics.pairwise import cosine_similarity
import re

# Load the medium spaCy model
nlp = spacy.load("en_core_web_lg")


def remove_mentions_and_hashtags(text):
    text = re.sub(r"@\w+", "", text)
    text = re.sub(r"#\w+", "", text)
    return text


def remove_numbers(text):
    text = re.sub(r"\d+", "", text)
    return text


def remove_punctuation(text):

    translator = str.maketrans("", "", string.punctuation)

    # Remove punctuation using the translation table
    text_without_punct = text.translate(translator)

    return text_without_punct


def remove_stopwords(text):
    filtered_sentence = []
    doc = nlp(text)
    for token in doc:
        if token.is_stop == False:
            filtered_sentence.append(token.text)
    return " ".join(filtered_sentence)


def lemmatize(text):
    doc = nlp(text)
    text = " ".join([token.lemma_ for token in doc])
    return text


def clean_text(text, to_lemmatize: bool = True):
    # Standardize text
    # text = standardize_accented_chars(text)

    # Remove URLs
    text = re.sub(r"http\S+", "", text)

    # Remove mentions and hashtags
    text = remove_mentions_and_hashtags(text)

    # Lowercase
    text = text.lower()

    # Remove punctuation
    text = remove_punctuation(text)

    # Remove numbers
    text = remove_numbers(text)

    # Remove all the special characters
    text = re.sub(r"\W", " ", text)

    # Remove stopwords
    text = remove_stopwords(text)

    # Substituting multiple spaces with single space
    text = re.sub(r"\s+", " ", text, flags=re.I)

    if to_lemmatize:
        text = lemmatize(text)

    return text


categories_df["clean_description"] = categories_df["description"].apply(
    lambda x: clean_text(x)
)
domains_df["clean_description"] = domains_df["description"].apply(
    lambda x: clean_text(x)
)

categories_df["description_vector"] = categories_df["clean_description"].apply(nlp)
domains_df["description_vector"] = domains_df["clean_description"].apply(nlp)

# %%
categories_df.to_csv("data/final_categories.csv", index=False)
domains_df.to_csv("data/final_domains.csv", index=False)

# %%
def find_best_match(cat_desc_vec, label_vectors):
    # Calculate similarities and return the index of the highest similarity
    similarities = [
        cat_desc_vec.similarity(label_desc) for label_desc in label_vectors
    ]
    return similarities.index(max(similarities))


# Convert domain vectors to a list for efficiency
label_vectors = domains_df["description_vector"].tolist()

# Find the best match for each category
categories_df["best_match_label_index"] = categories_df["description_vector"].apply(
    lambda x: find_best_match(x, label_vectors)
)

# Map the index to the actual domain name
categories_df["best_match_label"] = categories_df["best_match_label_index"].apply(
    lambda x: domains_df.iloc[x]["naics_label"]
)

# %%
categories_df
# Out:
#                                     label  \
# 0                 ATVs Dealers & Services
# 1                        Abortion Clinics
# 2       Accounting & Bookkeeping Services
# 3                      Acupuncture clinic
# 4                    Adhesives & Sealants
# ..                                    ...
# 598  Work Clothing & Protection Equipment
# 599                 Writers & Copywriters
# 600                            YMCA Camps
# 601                          Yoga Studios
# 602                                   Zoo
#
#                                            description  \
# 0    Businesses categorized under ATVs Dealers & Se...
# 1    Abortion Clinics provide medical services rela...
# 2    Accounting & Bookkeeping Services encompass a ...
# 3    An Acupuncture clinic is a healthcare facility...
# 4    Adhesives & Sealants encompass a diverse range...
# ..                                                 ...
# 598  Work Clothing & Protection Equipment pertains ...
# 599  Writers & Copywriters are skilled professional...
# 600  YMCA Camps offer structured programs and activ...
# 601  Yoga Studios offer a tranquil space for indivi...
# 602  A Zoo is a facility where a diverse collection...
#
#                                      clean_description  \
# 0    business categorize atvs dealer service specia...
# 1    abortion clinic provide medical service relate...
# 2    accounting bookkeeping service encompass range...
# 3    acupuncture clinic healthcare facility special...
# 4    adhesive sealant encompass diverse range produ...
# ..                                                 ...
# 598  work clothing protection equipment pertain spe...
# 599  writer copywriter skilled professional special...
# 600  ymca camp offer structured program activity de...
# 601  yoga studio offer tranquil space individual en...
# 602  zoo facility diverse collection wild animal ho...
#
#                                     description_vector  \
# 0    (business, categorize, atvs, dealer, service, ...
# 1    (abortion, clinic, provide, medical, service, ...
# 2    (accounting, bookkeeping, service, encompass, ...
# 3    (acupuncture, clinic, healthcare, facility, sp...
# 4    (adhesive, sealant, encompass, diverse, range,...
# ..                                                 ...
# 598  (work, clothing, protection, equipment, pertai...
# 599  (writer, copywriter, skilled, professional, sp...
# 600  (ymca, camp, offer, structured, program, activ...
# 601  (yoga, studio, offer, tranquil, space, individ...
# 602  (zoo, facility, diverse, collection, wild, ani...
#
#      best_match_label_index                                   best_match_label
# 0                        68                        Rental and Leasing Services
# 1                        76                                          Hospitals
# 2                        72                Administrative and Support Services
# 3                        75                    Ambulatory Health Care Services
# 4                        32                        Miscellaneous Manufacturing
# ..                      ...                                                ...
# 598                      84                             Repair and Maintenance
# 599                      57                              Publishing Industries
# 600                      85                      Personal and Laundry Services
# 601                      79  Performing Arts, Spectator Sports, and Related...
# 602                       1                  Animal Production and Aquaculture
#
# [603 rows x 6 columns]

# %%
business_df[:5]
# Out:
#             commercial_name  \
# 0               White Horse
# 1  Wealth Solution Partners
# 2                       PMG
# 3          TMP Capital PLLC
# 4            Genertek Power
#
#                                        business_tags  \
# 0  Tile Manufacturing | European Aesthetics Ceram...
# 1  Super and SMSF Services | Financial Planning a...
# 2  Fire and Water Cleanup Services | Mold Remedia...
# 3  Licensed in AL & FL | 203K Loans | 15-year Fix...
# 4  Industrial and Commercial Energy Storage | Ass...
#
#                                    short_description  \
# 0  White Horse is highly regarded as a tile trail...
# 1  WSP, Wealth Solution Partners, Financial Plann...
# 2  PMG General Solutions Inc. is an environmental...
# 3  TMP Capital PLLC Consulting Company Franklin M...
# 4  Genertek Power Ltd a UK electricity systems & ...
#
#                                          description  \
# 0  White Horse Ceramic Singapore is a leading man...
# 1  Wealth Solution Partners Pty Ltd is an indepen...
# 2  PMG General Solutions Inc. is an environmental...
# 3  TMP Capital PLLC Consulting Company, also know...
# 4  Genertek Power Limited is a privately-owned UK...
#
#                         main_business_category
# 0                                   Tile Store
# 1  Investment Consultants & Financial Advisors
# 2        Damage Restoration & Mold Remediation
# 3                             Mortgage Brokers
# 4                   Renewable energy companies

# %%
final_data = pd.merge(business_df, categories_df[['label','best_match_label_index','best_match_label']], left_on="main_business_category",right_on="label")
final_data.drop(columns=['label'], inplace=True)

# %%
final_data
# Out:
#                    commercial_name  \
# 0                      White Horse
# 1         Wealth Solution Partners
# 2                              PMG
# 3                 TMP Capital PLLC
# 4                   Genertek Power
# ...                            ...
# 626241  Global Golf Tech Solutions
# 626242                       Renko
# 626243                     Norstal
# 626244                    Acoustic
# 626245      PAPER MACHINE CLOTHING
#
#                                             business_tags  \
# 0       Tile Manufacturing | European Aesthetics Ceram...
# 1       Super and SMSF Services | Financial Planning a...
# 2       Fire and Water Cleanup Services | Mold Remedia...
# 3       Licensed in AL & FL | 203K Loans | 15-year Fix...
# 4       Industrial and Commercial Energy Storage | Ass...
# ...                                                   ...
# 626241  Manufacturing | Golf Academy | G Launch Monito...
# 626242  Latest Processing Technologies | E Gaskets for...
# 626243  Residential Buildings | Custom Project Service...
# 626244  Wood-based Acoustic Products Manufacturer | De...
# 626245  Detailed Machine Studies and Analytics | Scree...
#
#                                         short_description  \
# 0       White Horse is highly regarded as a tile trail...
# 1       WSP, Wealth Solution Partners, Financial Plann...
# 2       PMG General Solutions Inc. is an environmental...
# 3       TMP Capital PLLC Consulting Company Franklin M...
# 4       Genertek Power Ltd a UK electricity systems & ...
# ...                                                   ...
# 626241  The best personal golf launch monitor screen p...
# 626242  EPDM Rubber products from Renko can be found o...
# 626243  Norstal produces a broad range of steel struct...
# 626244  We are designed and manufactured in UAE, Acous...
# 626245  With Huatao innovative product portfolio of pa...
#
#                                               description  \
# 0       White Horse Ceramic Singapore is a leading man...
# 1       Wealth Solution Partners Pty Ltd is an indepen...
# 2       PMG General Solutions Inc. is an environmental...
# 3       TMP Capital PLLC Consulting Company, also know...
# 4       Genertek Power Limited is a privately-owned UK...
# ...                                                   ...
# 626241  Global Golf Tech Solutions is a company that s...
# 626242  RENKO is a company that has been producing hig...
# 626243  Norstal is a steel structure producer that spe...
# 626244  Acoustic.ae is a member of a UAE-based group o...
# 626245  Huatao Group, also known as Huatao Group, is a...
#
#                              main_business_category  best_match_label_index  \
# 0                                        Tile Store                      31
# 1       Investment Consultants & Financial Advisors                      64
# 2             Damage Restoration & Mold Remediation                      84
# 3                                  Mortgage Brokers                      64
# 4                        Renewable energy companies                       8
# ...                                             ...                     ...
# 626241                 Golf Courses & Country Clubs                      81
# 626242                   Fabricated Rubber Products                      27
# 626243                   Metal Fabrication Services                      27
# 626244              Building Material Manufacturers                      27
# 626245                   Paper & Cardboard Products                      20
#
#                                          best_match_label
# 0             Furniture and Related Product Manufacturing
# 1       Securities, Commodity Contracts, and Other Fin...
# 2                                  Repair and Maintenance
# 3       Securities, Commodity Contracts, and Other Fin...
# 4                                               Utilities
# ...                                                   ...
# 626241     Amusement, Gambling, and Recreation Industries
# 626242                            Machinery Manufacturing
# 626243                            Machinery Manufacturing
# 626244                            Machinery Manufacturing
# 626245            Printing and Related Support Activities
#
# [626246 rows x 7 columns]

# %%
final_data.to_csv('labelled_data.csv', index=False)

# %%
final_data[final_data['main_business_category'] == 'Beauty Salons']
# Out:
#                         commercial_name  \
# 243                       CARIDAD VIDRO
# 680     Azalea Beauty Consultancy India
# 1469                   BEAUTIFUL REMEDY
# 1674            Sogno The Salon Company
# 2244                    Eman Beauty Lab
# ...                                 ...
# 625702                     Mia's Beauty
# 625792           Jenyosola Beauty Salon
# 625972               Manhattan Nail Bar
# 626006      Grand Nails Lounge Ocotillo
# 626182           Cinderella Hair Castle
#
#                                             business_tags  \
# 243     On-location Services for Private Events | Brid...
# 680     Sourcing and Purchasing Services | Layout Plan...
# 1469    Waxing Services | Permanent Cosmetics | Facial...
# 1674    Personal Care Services | Hair Coloring Service...
# 2244    Beauty Treatments | Beauty Services | Retail |...
# ...                                                   ...
# 625702  Pedicure Services | Personal Care Services | W...
# 625792           Beauty Services | Personal Care Services
# 625972                             Personal Care Services
# 626006  Personal Care Services | Manicure and Pedicure...
# 626182  Brazilian Keratin Treatments for Hair | Brazil...
#
#                                         short_description  \
# 243     Welcome to CARIDAD VIDRO SHOP, wedding favors ...
# 680     Initial and ongoing training and support for S...
# 1469    BEAUTIFUL REMEDY is a beauty salon based in Ka...
# 1674    Sogno The Salon Company is a beauty salon base...
# 2244    Welcome to Eman Beauty Lab, our Nail Salon in ...
# ...                                                   ...
# 625702  Mia's Beauty is the perfect Nail Salon for any...
# 625792  Jenyosola Beauty Salon is a beauty salon based...
# 625972  Manhattan Nail Bar is a beauty salon based in ...
# 626006  Grand Nails Lounge Ocotillo at 3990 S Alma Sch...
# 626182  Cinderella Hair Castle is a top New York Hair ...
#
#                                               description  \
# 243     Caridad VIDRO is a professional hair and makeu...
# 680     Azalea Beauty Consultancy India is a company t...
# 1469    Beautiful Remedy LLC is a beauty company that ...
# 1674    Sogno The Salon Company is a beauty salon loca...
# 2244    Eman Beauty Lab is a nail salon located in Asc...
# ...                                                   ...
# 625702  Mia's Beauty is a nail salon located in the Ta...
# 625792  Jenyosola Beauty Salon is a beauty salon locat...
# 625972  Manhattan Nail Bar is a nail salon that offers...
# 626006  Grand Nails Lounge Ocotillo is a beauty salon ...
# 626182  Cinderella Hair Castle is a New York-based hai...
#
#        main_business_category  best_match_label_index  \
# 243             Beauty Salons                      41
# 680             Beauty Salons                      41
# 1469            Beauty Salons                      41
# 1674            Beauty Salons                      41
# 2244            Beauty Salons                      41
# ...                       ...                     ...
# 625702          Beauty Salons                      41
# 625792          Beauty Salons                      41
# 625972          Beauty Salons                      41
# 626006          Beauty Salons                      41
# 626182          Beauty Salons                      41
#
#                           best_match_label
# 243     Health and Personal Care Retailers
# 680     Health and Personal Care Retailers
# 1469    Health and Personal Care Retailers
# 1674    Health and Personal Care Retailers
# 2244    Health and Personal Care Retailers
# ...                                    ...
# 625702  Health and Personal Care Retailers
# 625792  Health and Personal Care Retailers
# 625972  Health and Personal Care Retailers
# 626006  Health and Personal Care Retailers
# 626182  Health and Personal Care Retailers
#
# [1768 rows x 7 columns]

# %%
description = "NU U 2 Hair & Beauty is a professional hair and beauty salon located in Milton Regis High Street, Sittingbourne. They offer a variety of hair and body treatments, including hair cutting and styling, as well as other beauty treatments such as waxing, eye treatments, facials, massage, body treatments and permanent make-up."

# %%
final_data["clean_description"] = final_data["description"].apply(
    lambda x: clean_text(x)
)

final_data["description_vector"] = final_data["clean_description"].apply(nlp)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 final_data["clean_description"] = final_data["description"].apply(
#       2     lambda x: clean_text(x)
#       3 )
#       5 final_data["description_vector"] = final_data["clean_description"].apply(nlp)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[27], line 2, in <lambda>(x)
#       1 final_data["clean_description"] = final_data["description"].apply(
# ----> 2     lambda x: clean_text(x)
#       3 )
#       5 final_data["description_vector"] = final_data["clean_description"].apply(nlp)
#
# Cell In[16], line 69, in clean_text(text, to_lemmatize)
#      66 text = re.sub(r"\W", " ", text)
#      68 # Remove stopwords
# ---> 69 text = remove_stopwords(text)
#      71 # Substituting multiple spaces with single space
#      72 text = re.sub(r"\s+", " ", text, flags=re.I)
#
# Cell In[16], line 33, in remove_stopwords(text)
#      31 def remove_stopwords(text):
#      32     filtered_sentence = []
# ---> 33     doc = nlp(text)
#      34     for token in doc:
#      35         if token.is_stop == False:
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\spacy\language.py:1049, in Language.__call__(self, text, disable, component_cfg)
#    1047     error_handler = proc.get_error_handler()
#    1048 try:
# -> 1049     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1050 except KeyError as e:
#    1051     # This typically happens if a component is not initialized
#    1052     raise ValueError(Errors.E109.format(name=name)) from e
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\spacy\pipeline\trainable_pipe.pyx:52, in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\spacy\pipeline\transition_parser.pyx:264, in spacy.pipeline.transition_parser.Parser.predict()
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\spacy\pipeline\transition_parser.pyx:285, in spacy.pipeline.transition_parser.Parser.greedy_parse()
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:334, in Model.predict(self, X)
#     330 def predict(self, X: InT) -> OutT:
#     331     """Call the model's `forward` function with `is_train=False`, and return
#     332     only the output, instead of the `(output, callback)` tuple.
#     333     """
# --> 334     return self._func(self, X, is_train=False)[0]
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\spacy\ml\tb_framework.py:34, in forward(model, X, is_train)
#      33 def forward(model, X, is_train):
# ---> 34     step_model = ParserStepModel(
#      35         X,
#      36         model.layers,
#      37         unseen_classes=model.attrs["unseen_classes"],
#      38         train=is_train,
#      39         has_upper=model.attrs["has_upper"],
#      40     )
#      42     return step_model, step_model.finish_steps
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\spacy\ml\parser_model.pyx:250, in spacy.ml.parser_model.ParserStepModel.__init__()
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\with_array.py:42, in forward(model, Xseq, is_train)
#      40     return model.layers[0](Xseq, is_train)
#      41 else:
# ---> 42     return cast(Tuple[SeqT, Callable], _list_forward(model, Xseq, is_train))
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\with_array.py:77, in _list_forward(model, Xs, is_train)
#      75 lengths = NUMPY_OPS.asarray1i([len(seq) for seq in Xs])
#      76 Xf = layer.ops.flatten(Xs, pad=pad)
# ---> 77 Yf, get_dXf = layer(Xf, is_train)
#      79 def backprop(dYs: ListXd) -> ListXd:
#      80     dYf = layer.ops.flatten(dYs, pad=pad)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\residual.py:41, in forward(model, X, is_train)
#      38     else:
#      39         return d_output + dX
# ---> 41 Y, backprop_layer = model.layers[0](X, is_train)
#      42 if isinstance(X, list):
#      43     return [X[i] + Y[i] for i in range(len(X))], backprop
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
#     [... skipping similar frames: Model.__call__ at line 310 (1 times)]
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\maxout.py:52, in forward(model, X, is_train)
#      50 W = model.get_param("W")
#      51 W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 52 Y = model.ops.gemm(X, W, trans2=True)
#      53 Y += model.ops.reshape1f(b, nO * nP)
#      54 Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:

# %%
final_data

# %%
test_df = pd.read_csv("data/data.csv")
test_df
# Out:
#      Unnamed: 0  company_id  \
# 0             0          84
# 1             1         115
# 2             2          50
# 3             3          92
# 4             4          88
# ..          ...         ...
# 101         101          28
# 102         102         116
# 103         103           6
# 104         104          24
# 105         105           5
#
#                                                round_1  \
# 0                                        Advisory Care
# 1                                 PPK Mining Equipment
# 2                               First Tracks Lawn Care
# 3                                New Golden Furnishers
# 4                                    Lilac City Septic
# ..                                                 ...
# 101                                        Purple Pixl
# 102                                     Pasargad Jonub
# 103                            Davis Business Machines
# 104                                   High Desert Tool
# 105  Heart to Heart International is a non-profit o...
#
#                                               answer  \
# 0                621 Ambulatory Health Care Services
# 1                  213 Support Activities for Mining
# 2            561 Administrative and Support Services
# 3    337 Furniture and Related Product Manufacturing
# 4      562 Waste Management and Remediation Services
# ..                                               ...
# 101                       811 Repair and Maintenance
# 102     237 Heavy and Civil Engineering Construction
# 103          423 Merchant Wholesalers, Durable Goods
# 104   326 Plastics and Rubber Products Manufacturing
# 105                            624 Social Assistance
#
#                                                round_2  \
# 0    Hygiene Services | One-on-one Attention and Ca...
# 1    High & Low Seam Drills | Ventilation Solutions...
# 2    Weekly Mowing | Driveway Plowing Services | Mu...
# 3    Staff Task Computer Chairs Supplier | Mesh Bac...
# 4    Clean-Out Installation | Line Replacement Serv...
# ..                                                 ...
# 101  Battery Replacement | Viruses Removal | Front ...
# 102  Infrastructure Project Management | Design and...
# 103  Managed IT Services | Document Scanners | Fax ...
# 104  Aerospace Molds Supplier | Automotive Molds Di...
# 105                             Social Services & NGOs
#
#                                                round_3  \
# 0    Advisory Care is a home health care services p...
# 1    PPK Mining Equipment is the solution partner o...
# 2    First Tracks Lawn Care, LLC prides itself on p...
# 3    New Golden Furnishers Co - Manufacturer of Dou...
# 4    Lilac City Septic services residential & comme...
# ..                                                 ...
# 101  Purple Pixl offers fast & effective repair ser...
# 102  Having a brilliant background and well-trained...
# 103  Since May 13, 1963, Davis Business Machines ha...
# 104  High Desert Tool specializes in large mold man...
# 105                                     Heart to Heart
#
#                                                round_4  \
# 0    Advisory Care Pty Ltd is a company that provid...
# 1    PPK Mining Equipment is a company that special...
# 2    First Tracks Lawn Care, LLC is a lawn care com...
# 3    New Golden Furnishers Co is a furniture manufa...
# 4    Lilac City Septic Services Co is a family-owne...
# ..                                                 ...
# 101  Purple Pixl is a technology and electronics re...
# 102  Pasargad Jonub is a private joint stock compan...
# 103  Davis Business Machines is a company that has ...
# 104  High Desert Tool is a company that specializes...
# 105  Global Health Information Provider | Humanitar...
#
#                                                round_5
# 0                                     Home Health Care
# 1                             Mining & Gas Exploration
# 2                          Landscaping & Lawn Services
# 3                                     Office Furniture
# 4                  Garbage Collection & Waste Disposal
# ..                                                 ...
# 101                            Phone Repair & Services
# 102                         Civil Engineering Services
# 103                                    Office Supplies
# 104                         Injection Molding Services
# 105  As a healthcare nonprofit organization, Heart ...
#
# [106 rows x 8 columns]

# %%
label_vectors = final_data["commercial_name"].apply(lambda x: clean_text(x)).tolist()
label_vectors
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 label_vectors = final_data["commercial_name"].apply(lambda x: clean_text(x)).tolist()
#       2 label_vectors
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[12], line 1, in <lambda>(x)
# ----> 1 label_vectors = final_data["commercial_name"].apply(lambda x: clean_text(x)).tolist()
#       2 label_vectors
#
# Cell In[4], line 75, in clean_text(text, to_lemmatize)
#      72 text = re.sub(r"\s+", " ", text, flags=re.I)
#      74 if to_lemmatize:
# ---> 75     text = lemmatize(text)
#      77 return text
#
# Cell In[4], line 41, in lemmatize(text)
#      40 def lemmatize(text):
# ---> 41     doc = nlp(text)
#      42     text = " ".join([token.lemma_ for token in doc])
#      43     return text
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\spacy\language.py:1049, in Language.__call__(self, text, disable, component_cfg)
#    1047     error_handler = proc.get_error_handler()
#    1048 try:
# -> 1049     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1050 except KeyError as e:
#    1051     # This typically happens if a component is not initialized
#    1052     raise ValueError(Errors.E109.format(name=name)) from e
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\spacy\pipeline\trainable_pipe.pyx:52, in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\spacy\pipeline\tok2vec.py:126, in Tok2Vec.predict(self, docs)
#     124     width = self.model.get_dim("nO")
#     125     return [self.model.ops.alloc((0, width)) for doc in docs]
# --> 126 tokvecs = self.model.predict(docs)
#     127 return tokvecs
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:334, in Model.predict(self, X)
#     330 def predict(self, X: InT) -> OutT:
#     331     """Call the model's `forward` function with `is_train=False`, and return
#     332     only the output, instead of the `(output, callback)` tuple.
#     333     """
# --> 334     return self._func(self, X, is_train=False)[0]
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\with_array.py:42, in forward(model, Xseq, is_train)
#      40     return model.layers[0](Xseq, is_train)
#      41 else:
# ---> 42     return cast(Tuple[SeqT, Callable], _list_forward(model, Xseq, is_train))
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\with_array.py:77, in _list_forward(model, Xs, is_train)
#      75 lengths = NUMPY_OPS.asarray1i([len(seq) for seq in Xs])
#      76 Xf = layer.ops.flatten(Xs, pad=pad)
# ---> 77 Yf, get_dXf = layer(Xf, is_train)
#      79 def backprop(dYs: ListXd) -> ListXd:
#      80     dYf = layer.ops.flatten(dYs, pad=pad)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\residual.py:41, in forward(model, X, is_train)
#      38     else:
#      39         return d_output + dX
# ---> 41 Y, backprop_layer = model.layers[0](X, is_train)
#      42 if isinstance(X, list):
#      43     return [X[i] + Y[i] for i in range(len(X))], backprop
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
#     [... skipping similar frames: Model.__call__ at line 310 (1 times)]
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\thinc\layers\maxout.py:52, in forward(model, X, is_train)
#      50 W = model.get_param("W")
#      51 W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 52 Y = model.ops.gemm(X, W, trans2=True)
#      53 Y += model.ops.reshape1f(b, nO * nP)
#      54 Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:

# %%
clean_dataset = pd.read_csv("data/cleaned_dataset.csv")
clean_dataset
# Out:
#         Unnamed: 0             commercial_name  \
# 0                0                 White Horse
# 1                1    Wealth Solution Partners
# 2                2                         PMG
# 3                3            TMP Capital PLLC
# 4                4              Genertek Power
# ...            ...                         ...
# 613326      613326                 Track Audio
# 613327      613327  Global Golf Tech Solutions
# 613328      613328                       Renko
# 613329      613329                     Norstal
# 613330      613330      PAPER MACHINE CLOTHING
#
#                                             business_tags  \
# 0       Tile Manufacturing | European Aesthetics Ceram...
# 1       Super and SMSF Services | Financial Planning a...
# 2       Fire and Water Cleanup Services | Mold Remedia...
# 3       Licensed in AL & FL | 203K Loans | 15-year Fix...
# 4       Industrial and Commercial Energy Storage | Ass...
# ...                                                   ...
# 613326  Manufacturing | ISO 9001 Certification | Suppo...
# 613327  Manufacturing | Golf Academy | G Launch Monito...
# 613328  Latest Processing Technologies | E Gaskets for...
# 613329  Residential Buildings | Custom Project Service...
# 613330  Detailed Machine Studies and Analytics | Scree...
#
#                                         short_description  \
# 0       White Horse is highly regarded as a tile trail...
# 1       WSP, Wealth Solution Partners, Financial Plann...
# 2       PMG General Solutions Inc. is an environmental...
# 3       TMP Capital PLLC Consulting Company Franklin M...
# 4       Genertek Power Ltd a UK electricity systems & ...
# ...                                                   ...
# 613326  Track Audio - Speaker Stands and Isolation Mou...
# 613327  The best personal golf launch monitor screen p...
# 613328  EPDM Rubber products from Renko can be found o...
# 613329  Norstal produces a broad range of steel struct...
# 613330  With Huatao innovative product portfolio of pa...
#
#                                               description  \
# 0       White Horse Ceramic Singapore is a leading man...
# 1       Wealth Solution Partners Pty Ltd is an indepen...
# 2       PMG General Solutions Inc. is an environmental...
# 3       TMP Capital PLLC Consulting Company, also know...
# 4       Genertek Power Limited is a privately-owned UK...
# ...                                                   ...
# 613326  Track Audio Ltd is a British company based in ...
# 613327  Global Golf Tech Solutions is a company that s...
# 613328  RENKO is a company that has been producing hig...
# 613329  Norstal is a steel structure producer that spe...
# 613330  Huatao Group, also known as Huatao Group, is a...
#
#                              main_business_category  \
# 0                                        Tile Store
# 1       Investment Consultants & Financial Advisors
# 2             Damage Restoration & Mold Remediation
# 3                                  Mortgage Brokers
# 4                        Renewable energy companies
# ...                                             ...
# 613326                           Electronics Stores
# 613327                 Golf Courses & Country Clubs
# 613328                   Fabricated Rubber Products
# 613329                   Metal Fabrication Services
# 613330                   Paper & Cardboard Products
#
#             commercial_name_clean  \
# 0                     white horse
# 1         wealth solution partner
# 2                             pmg
# 3                tmp capital pllc
# 4                  genertek power
# ...                           ...
# 613326                track audio
# 613327  global golf tech solution
# 613328                      renko
# 613329                    norstal
# 613330     paper machine clothing
#
#                                       business_tags_clean  \
# 0       tile manufacturing european aesthetic ceramic ...
# 1       super smsf service financial planning investme...
# 2       fire water cleanup service mold remediation re...
# 3       license al fl 203k loan 15year fix mortgage mo...
# 4       industrial commercial energy storage asset man...
# ...                                                   ...
# 613326  manufacture iso 9001 certification support sol...
# 613327  manufacture golf academy g launch monitor scre...
# 613328  late processing technology e gasket facade joi...
# 613329  residential building custom project service st...
# 613330  detail machine study analytic screen dryer sho...
#
#                                   short_description_clean  \
# 0       white horse highly regard tile trailblazer des...
# 1       wsp wealth solution partner financial planning...
# 2       pmg general solutions inc environmental remedi...
# 3       tmp capital pllc consult company franklin mort...
# 4       genertek power ltd uk electricity system uk in...
# ...                                                   ...
# 613326  track audio speaker stand isolation mount engi...
# 613327  good personal golf launch monitor screen prote...
# 613328  epdm rubber product renko find roof window fac...
# 613329  norstal produce broad range steel structure re...
# 613330  huatao innovative product portfolio paper mach...
#
#                                         description_clean  \
# 0       white horse ceramic singapore lead manufacture...
# 1       wealth solution partner pty ltd independent fi...
# 2       pmg general solutions inc environmental remedi...
# 3       tmp capital pllc consult company know franklin...
# 4       genertek power limit privatelyowne uk investme...
# ...                                                   ...
# 613326  track audio ltd british company base amersham ...
# 613327  global golf tech solution company specialize p...
# 613328  renko company produce highquality epdm rubber ...
# 613329  norstal steel structure producer specialize hi...
# 613330  huatao group know huatao group lead global sup...
#
#                    main_business_category_clean  \
# 0                                    tile store
# 1       investment consultant financial advisor
# 2           damage restoration mold remediation
# 3                               mortgage broker
# 4                      renewable energy company
# ...                                         ...
# 613326                         electronic store
# 613327                 golf course country club
# 613328                 fabricate rubber product
# 613329                metal fabrication service
# 613330                  paper cardboard product
#
#                                               naics_label
# 0       Building Material and Garden Equipment and Sup...
# 1             Funds, Trusts, and Other Financial Vehicles
# 2               Waste Management and Remediation Services
# 3            Credit Intermediation and Related Activities
# 4                                               Utilities
# ...                                                   ...
# 613326  Furniture, Home Furnishings, Electronics, and ...
# 613327     Amusement, Gambling, and Recreation Industries
# 613328         Plastics and Rubber Products Manufacturing
# 613329             Fabricated Metal Product Manufacturing
# 613330                                Paper Manufacturing
#
# [613331 rows x 12 columns]

# %%
clean_dataset["commercial_name_clean"] = clean_dataset["commercial_name"].astype(str)

# %%
clean_dataset["name_vector"] = clean_dataset["commercial_name_clean"].apply(nlp)

# %%
label_vectors = clean_dataset["name_vector"].tolist()
label_vectors
# Out:
# [White Horse,
#  Wealth Solution Partners,
#  PMG,
#  TMP Capital PLLC,
#  Genertek Power,
#  HQ Machine Tech,
#  iFleet,
#  Strategic Benefit Resources,
#  Billington Holdings,
#  Haram Couture,
#  Regina Dent,
#  Flagg Consulting,
#  Nerveless Nocks,
#  Satatuote,
#  H2O Vend,
#  Chrome Horse Saloon,
#  Emily Brown Physical Therapy,
#  Tax Service,
#  Wholesale Trailers,
#  Shivashrit Foods,
#  Preston Dental Care,
#  BAHRAIN WORKSHOP COMPANY W.L.L,
#  Partitions,
#  Travell,
#  LEISIDUN,
#  Geological Service,
#  3H DECOR,
#  Al Rahimah,
#  Al Amwaj,
#  Adyjohns,
#  Forschene,
#  Black Oak Wilderness,
#  SideKick,
#  Hiap Shing,
#  Virginia Eagle,
#  Auto-jet,
#  RAP Power Industries,
#  Sheet Metal Crafters,
#  They Poop,
#  Preps Recruiting,
#  East Calais Community Trust,
#  The Fresh Toast,
#  Ship Finance Maritime,
#  NuGen Systems,
#  VAI Capital,
#  HIKS,
#  Cleveland Mica,
#  Green Bus Brewing,
#  Teleli Golf Club,
#  Ormond Aircraft,
#  HITV Lab,
#  Palermo Lubricants,
#  Shri Bharat Agencies,
#  Stoneage Granite and Marble,
#  77 STORAGE,
#  White Water Marine Hardware,
#  Star of the Sea Seafood,
#  Emvo Techniek,
#  Floors and More,
#  Novacan,
#  Gerbon Hardware,
#  Radiation,
#  Brick Corner,
#  Eureka Aircraft,
#  Florida Title Services,
#  L.A. Metropolitan,
#  Custom Edge,
#  MCR Labs,
#  Grace Hopper,
#  Glomacht,
#  Family Crisis Shelter,
#  BARCODE SERVICES,
#  Migs Tints,
#  Produstrial,
#  Ovenware,
#  Trans seasons group,
#  Colendor,
#  City Connect Bus,
#  CHP Finishing,
#  Multipix,
#  Mold Masters,
#  Greenwich Forge,
#  Lehar Pharma Distributors,
#  Revoh,
#  Global Space Exchange,
#  Key2Cell,
#  Seahch,
#  Cooper & Company Interior Design Services,
#  Sheraz Cargo,
#  The Vape Boutique,
#  Raseet,
#  Fine Patio Design,
#  Next Level Metal Polishing,
#  LAKA,
#  OMIC,
#  SureTrac Systems,
#  Delphi Music Group,
#  Rekindle Wellness,
#  Balmy Beach Community Day Care,
#  Stove and Fireplace Fitters,
#  Ideal Supplies,
#  Criswell Commercial,
#  Aire Candles,
#  Findlay Food Coatings,
#  Shri Ujjwal Communication,
#  Upstate Glass Tempering,
#  Andrew Sell My Car Louisville,
#  Arraytech,
#  Union Steel,
#  Appalachian Electronic Instruments,
#  King Arts Tattoo,
#  MTC Global Trading,
#  Hanover Financial Solutions,
#  FPA Legal Defense,
#  Assisted Living Near Me,
#  Spectrum Resource Group,
#  MGENPower,
#  Bare Bones Ice,
#  KRL,
#  Laboratory Glass Apparatus,
#  Ritossa,
#  Ocsun,
#  Knowledgeworld,
#  Camp Live Oak,
#  HCM TradeSeal,
#  JEM Contractors,
#  Cloud Ocean Line,
#  Cardiac Sports,
#  Kurt,
#  Financika,
#  Osmonic Corporation,
#  MyEyeStore,
#  Graphx Printing,
#  Sutherland adventure,
#  Magnolia Power Group,
#  Imaginatuluz,
#  Housing To Behold,
#  PSH PowerWash Co.,
#  Abroad Experience,
#  Variantyx,
#  OMNI AR,
#  Coles Gun Shop,
#  SWORDHF,
#  Mahadev Hotels,
#  Resmer Power,
#  Inspirations By Elegance,
#  Canine Angels,
#  Social Media Investigations,
#  Earlham,
#  The Infusion Clinic,
#  XPMCARINGWORLD,
#  King Asillion,
#  Kehuco,
#  ArtSource Studio,
#  Community Science,
#  Akinleye Cement Depot,
#  Vector Fuels,
#  Spray Foam Equipment,
#  Capstone Plastering,
#  Tech-Sharp Enviro,
#  Blackrock Cellar,
#  Cal State Renovations,
#  The Rowan Atlee Foundation,
#  Static charging,
#  Central Home Delivery 2010,
#  The Wendell Historical Society,
#  Apex Herbals,
#  Capital Sanitary,
#  Nortons Floorsanding,
#  U-Frame-It Gallery,
#  Paras Steel Corporation,
#  REIAsure,
#  Santos Timber Company,
#  Beta Solutions,
#  SwissKnowledge,
#  All Parrot Products,
#  MxV,
#  Connie Deckert,
#  Peter Petrou Fitness,
#  Altman Plants,
#  Qihui Cases,
#  Pleasant Hill Excavators,
#  TREE DIMENSIONAL,
#  Expedite All,
#  Ennis Top Pizza,
#  Bunelle,
#  Economics,
#  NewPath Health Solutions,
#  PDI Health,
#  EONSLY,
#  Giorgio Luxury,
#  Dnyanjyoti Institute Of Fashion designing,
#  Oxley Garage Doors,
#  Infrastructure Unlimited,
#  Amcor Carpets & Interiors,
#  Iran Sang Ara,
#  J.I.K ENGINEERING COMPANY LIMITED,
#  Octava,
#  Riverview Drywall and Paint,
#  1905 Candle Company,
#  Xeration Services,
#  Sure Filter,
#  Oceans Logistix,
#  Richmond Beach Library,
#  Vin2U Wine Group,
#  The Fitting Company,
#  The Beer Room,
#  DewEze,
#  Real Hosts,
#  Timber Tomorrow,
#  New York Thermal Systems,
#  Collectorshells,
#  Natural Gallery,
#  MSI Avionics,
#  MK Paper Packaging,
#  HRS Process Systems,
#  Valley Transmission,
#  Yeti Electric Services,
#  STS Rent a Car,
#  APP Lifting,
#  Lexington Glassworks,
#  JLE TRADING,
#  Eurobots,
#  CCL Container,
#  NATE Health,
#  BALUNGISI,
#  Devin Systems,
#  Hallier Reed,
#  Quality Valve Repair,
#  Florence Memorial Gardens,
#  Knight Mobile Homes,
#  Spacegen,
#  EC Grow,
#  Rockfalls Skills,
#  Linked Electronics,
#  Lakeside Sundry,
#  King Records,
#  Zone Central,
#  Lai To Li,
#  Deep Fryer,
#  Khemani Group,
#  StageLease,
#  Wooten Vision Care,
#  CARIDAD VIDRO,
#  Leagend,
#  Portable Toilets,
#  East View Housing,
#  Cosmopack,
#  Crest V Drones,
#  Hampton Festival,
#  Luxe & Speed,
#  Nexgarden,
#  FLOW STREAM,
#  Smokestack,
#  Advanced Enertech,
#  Holloways Beach Sports Club,
#  Austin Welcome Center,
#  Creative Energy Designs,
#  Australian Organic,
#  Melodi Horne,
#  Aqleem Maritime,
#  Green Orchard Group,
#  Car Loan Hunter,
#  Jungle Guilds,
#  Sharon Woods,
#  Nashville Anesthesia,
#  Safety Guard,
#  Rhenus Corby,
#  ElderSong,
#  Vasa Concept,
#  AD EXPERTS MEDIA,
#  Mattress By Appointment,
#  Mahavir Car Rental,
#  Turkey Creek HDD,
#  O&O Candle Co.,
#  Concrete Designs,
#  CoLinx,
#  Ezraiderfl,
#  Treasure Coast Sleep,
#  Amalay,
#  Datatronics,
#  OEM Protector,
#  HAGIHARA MERIYASU,
#  Harveys,
#  Harvest Liquor Shoppe,
#  Titan Roofing,
#  Delta Alloys,
#  CluBarham,
#  Accessible Orlando,
#  NG GRANITE,
#  Al Rais Cargo,
#  Lemacks Cattle,
#  Hande,
#  Joint Office of Energy and Transportation,
#  Premier Seafoods,
#  Hidden River,
#  Olathe Karate Academy,
#  Aritas Vinyl,
#  Unistar,
#  The Retail Summit,
#  CCT Underground,
#  Krome Metal Chemicals,
#  Ridge View Investments,
#  Etransplus,
#  Shenzhen Magical,
#  Austin and Hall,
#  Bev Fusion,
#  Gaylord,
#  City Casting,
#  Bratislava Airport,
#  Apexsopicglobal,
#  Tankwash,
#  CANNON FENCING ACADEMY,
#  Abernethy Videography,
#  Kenaula,
#  Matthews Design,
#  Dream Cutter,
#  T. L. Faison's Funeral Care,
#  Orion's Fitness,
#  HAMMBREAKER,
#  Kames Country Club,
#  PanelBuild,
#  Advanced Security Solutions,
#  Market Title,
#  Wfubmc,
#  Pentagon Marine,
#  Magic Cook India,
#  Sunsai Consulting Services,
#  International Enterprises,
#  Rhine River Storage,
#  City Site,
#  GaWun Supplies,
#  Mackcrete,
#  B. Elevated Candle Bar,
#  Maximum Plus,
#  Outdoor Innovations,
#  Ahar,
#  DACAAI,
#  Dirt-Tech Excavation,
#  LunchBox Fitness,
#  Sea Start,
#  Pacific Promos,
#  Fail-Safe Solutions,
#  Zada Holdings,
#  JET AND MORE,
#  APIC,
#  Shraddha Techno,
#  Gryphon Consulting,
#  Falcon Valves,
#  SIDLER Website,
#  Garden To Pan Kitchen,
#  Halstead Quinn,
#  Orbio Agro,
#  ANTARA Organics,
#  Anchor Milk Otago,
#  Kurtwave,
#  Bristlecone,
#  Furrever Dog Training,
#  Ace Wellbeing,
#  Rembrandt,
#  Excel Energy,
#  BIOCHEMIZE,
#  Meal Chaser,
#  AL ARBEAA,
#  Elevation Barbershop,
#  We Fix PCs,
#  Advanced Pavers,
#  Richardson Radiator,
#  OMS,
#  Powerwerks,
#  Reliance Mine,
#  Same Day Dumpster Rental San Francisco,
#  Supreme Life,
#  Chariots of Hire,
#  LYSPI,
#  Selectric Artists,
#  Z Electric Vehicle,
#  Rjm Junk Removal,
#  BHAUMIK TRADING,
#  Archer Wealth,
#  Royal Oak Chiropractic,
#  SPADER,
#  Hek Windscreens,
#  16 Handles,
#  Turnpike Audio,
#  Schiffer on Re-Insurance,
#  Palm Beach Locksmith & Keys,
#  Purulia Metal Casting,
#  Pine Rivers Bearings,
#  Peapodandco,
#  Regatron,
#  Maxboat Marine,
#  Spinergy Emotions,
#  Fusion Bollywood,
#  ARRES CAPITAL,
#  Affordable insulatio,
#  Sandy Adams Properties,
#  GREENLANDS TECH LOGISTICS LIMITED,
#  Mandarin Fireworks,
#  Gymintensity,
#  Vanquish Crane,
#  Golden Mean Calipers,
#  Vergeconnect,
#  Granite concrete,
#  DbFace,
#  Down Nature,
#  Regal Tax,
#  AdHooked,
#  Peter Mills Property,
#  BMOP,
#  TOMLIN,
#  Championship Martial Arts,
#  Hatz,
#  Hungry Hook Farm,
#  Latinos for Healthcare Equity,
#  MELLUM CONSTRUCTION,
#  Omaha Eye,
#  Hartwell Manufacturing,
#  MK Quilts,
#  Kindred Funeral Home,
#  Ideal Toys Direct,
#  Petro Systems,
#  Cater Chiropractic Clinic,
#  Arbor Pro of Mississippi,
#  HUN AW,
#  Emergency Care Group,
#  Bahrawi,
#  Convenience Best Shipping Hardware Retail,
#  Diamond Services,
#  Tiletech Solutions,
#  Brick League,
#  Randen Electric,
#  Tempo Traveller Hire,
#  Freedom Convention Services,
#  Siasa Place,
#  Morooka Rental,
#  MERRITT & GRINSTEAD,
#  Zale Mortgage,
#  Stratevise,
#  Road Call Repair,
#  MCF technologies,
#  HECPA Financial,
#  Jack the Roofer,
#  Dennaoui,
#  DECCA TRADING LIMITED,
#  NEW FORCE BOXING,
#  Garage Door Repair Rialto CA,
#  Coal Field Flooring,
#  Ship Shape Financial,
#  V-max Power,
#  Nehal Naturals,
#  Taylor's Drone Photography & Video,
#  Cake Point,
#  Central States Hose,
#  Care Free Medical,
#  Helixagon,
#  OPMOD,
#  Eco Pro Tech,
#  Big Blue Trucking,
#  Cooper Myles,
#  Sterling Vending,
#  CORE Entertainment Group,
#  Benelinx,
#  Alfred G Pearce,
#  Harbingers of Truth,
#  Tank Containers,
#  GTA Auto Service,
#  Kazia Productions,
#  Vilin Bio Med,
#  Northstar,
#  NEXT GENERATION MATERIALS,
#  Hawaii Property Insurance Association,
#  Sydney Security Doors & Flyscreens,
#  AVISTA Green,
#  Max 7 Cleaning,
#  Leo Merch International,
#  Skellerup Rubber Services,
#  Pulselive,
#  Stable Vehicle Contracts,
#  Higie Liquor Store,
#  Equitium,
#  Teloptimize,
#  Arenson Office Furnishings,
#  Erso Capital,
#  Fife Golf Studio,
#  CMC SKY,
#  Mailboxes,
#  Rockdale Depot,
#  Commander,
#  The Dance Company India,
#  Antibody Society,
#  Timepiece Fix,
#  Lucas Angels,
#  Joy Guitar,
#  Retro Roofing & Construction,
#  Aquadeep Drilling,
#  Historic Electric Vehicle Foundation,
#  Gateej Engineering,
#  STARSAIL,
#  IFPW Foundation,
#  Hanasa Plus,
#  Team Go Get It,
#  Plug-in Digital,
#  Moon and Mana,
#  Active Concepts,
#  Thai Silp Jewelry,
#  Pretty Prints Partyware & Event Decor,
#  Wali Productions,
#  Oroton,
#  Matter Unlimited,
#  Mirfin Valuation Services,
#  Metals4U,
#  Perfect Cocktail,
#  Rocco Espresso,
#  Innovative Controls,
#  Ocean Integrated Wellness,
#  Madhur Metals,
#  Luc Van Lierde,
#  Pinecone Trading Co.,
#  Glaze Distributing,
#  Blaser Mills,
#  NOMADISMO MEDICAL,
#  Bilse,
#  PACK N TRADE,
#  Red Star Transportation,
#  Tastes of Tampa Bay,
#  Hummingbird Solutions,
#  Daily Essentials LLC USA,
#  Formic,
#  Avamels Printing Solutions,
#  Silver Creek Machine,
#  Paul L. Jansen & Son,
#  Mallof,
#  Waterloo Plastering,
#  Escrow Showcase,
#  The Very Good,
#  National Transport Museum,
#  First Class Quality Painting,
#  Inspire Recovery,
#  SPARE TIME SHOP,
#  Evergreen Retirement Home,
#  Mortabond,
#  MEGA LED LIGHTING,
#  Halifax Halal Poultry,
#  The Mortgage Selection Bureau,
#  Dhiverse,
#  DR. JASNA'S AYURVEDA,
#  Sattva Mosaics,
#  Nanette Cameron School,
#  Wellness Campaign,
#  Georgia Honey Bee,
#  SHR Training,
#  Clipper Kings Barber School,
#  Blue AQUA,
#  Elwafaaonline,
#  Vaibhav Consulting,
#  Bhargavi Safety Nets,
#  Epic Jet,
#  K9 Cane Corso,
#  YG Rail,
#  INK PICTURES,
#  Cellnet,
#  Bullock Agency,
#  Yard out of Hand,
#  Gill Welding,
#  Luxury Chandelier,
#  Arlington Citizen Police Academy,
#  Phillips Interiors,
#  Roachwood,
#  Ocean Formulations,
#  Elite Turf,
#  Vastu Spandan,
#  FloatDocks,
#  Visione 360,
#  Moreind,
#  WMH Developments,
#  Easy Tie Shoelaces,
#  Ace My App,
#  Lucabella Furniture,
#  Hegnes Design,
#  Naylor Nutrition,
#  Brecknock Orchard,
#  Barlow Tool & Machine,
#  DAPCO Industries,
#  SanRi Pack,
#  Glomation,
#  Rush Tees & Signs,
#  Ham-Kok,
#  ESS,
#  Sgaier Truss,
#  Kingberg,
#  Rama Maintenance,
#  Lazrtek,
#  Shaan Printing,
#  Najah Al Madina,
#  Top Spices,
#  New Accountant,
#  Eleca,
#  ATX Promotions,
#  Marine Garden,
#  Nephron Dental Supply,
#  Merrilees Hardware,
#  C3 Studio Pilates,
#  Rosman Fire Rescue,
#  Propaganda,
#  Lins Lace,
#  Cloud 9,
#  Panthea Capital,
#  Oakville United Taxi,
#  OLD ORCHARD MOBILE NOTARY,
#  Clean Burn,
#  Greenway Environmental,
#  Low Voltage,
#  Resort Talent,
#  Gurukrupa Engineering Works,
#  Pleatco,
#  Hyphen hotel,
#  Hair Care Clinics,
#  Sasha Interiors,
#  Trident Partners Asia,
#  Hydra Service,
#  Bille Bus,
#  Sierra Madre Landscape,
#  PRIME AROMA FOODS,
#  MarylandOnline,
#  Ultimate Interfaces,
#  UK Playing Card,
#  Alloy Specialty,
#  Bear Creek,
#  Arctic Beagle,
#  The Pewter Dragon,
#  Diamond Cements,
#  Suppliable,
#  Vultrex,
#  BPH Equipment,
#  MM2 ASIA,
#  Hiking adventures oman,
#  Melior Clinics,
#  CGRG,
#  Fortune Forex Trade,
#  Goodness Me,
#  Details Permanent Cosmetics,
#  Walling Systems,
#  Complete Automation Design,
#  Fairwell,
#  Monarch Homes,
#  The Good Scents Company,
#  M.N. Institute of Teacher's Training,
#  Mambopoint,
#  PSI Global,
#  A Big Indian Story,
#  Pro-Pak Industries,
#  Jarrahfall,
#  Sunita Chain,
#  Integrated Motor Systems,
#  Chelten House,
#  Lokesh Machines,
#  Professional Management Inc.,
#  Weakland's,
#  Friendwell,
#  SuperGlass FL,
#  Celebilly,
#  Mercia Refrigeration,
#  Tripak Industries,
#  Reyna's Dispatch,
#  Dunwell Elevator,
#  Signatory Contractors,
#  Samco Alloys,
#  Team AB Real,
#  Monica Taylor,
#  Open Field Farm,
#  Exocom,
#  Montebello,
#  Last Looks Chicago,
#  M. Sulaiman Trade Centre,
#  Roadwell Contracting,
#  DP Industries,
#  Delta Sales,
#  Showroom,
#  Aerial Elite Solutions,
#  Azalea Beauty Consultancy India,
#  Bluechip Systems,
#  Corks Wine & Spirits,
#  Powell Machine,
#  MCO Events,
#  Badger Buds,
#  Synxbnk,
#  SAM Transport,
#  Global Gateways,
#  Yesteryear Restorations,
#  Fickle Fowl Farms,
#  Gracese,
#  Aly Daly,
#  Noor Al-Mizan,
#  Aesthetic Bureau,
#  Star Timber,
#  Purpose Public Affairs,
#  DUTCH FOOD DELIGHTS,
#  Providence Building Supply,
#  Hikmat Pump,
#  Palm Automation,
#  Faraday Fine Foods,
#  Ignite Skill Academy,
#  Symonds Ecology,
#  Southside Trailer,
#  The Tire Terminal,
#  Filtech,
#  RI Packing,
#  Hilliard,
#  Pacific Footwear Company,
#  Healthcare Quality Systems,
#  WALABAX,
#  JS ElectroMate,
#  HomePro Financial,
#  Roads to Refuge,
#  Research and Testing Laboratory,
#  Med Weight Loss RX,
#  Ausfarm,
#  Trade Verge,
#  QueenBoho,
#  Bouk,
#  ELSE Logistics,
#  Plant Wines,
#  Akunna Martata Limited,
#  MAPH,
#  Palmetto Hardware,
#  Charstove,
#  World Expressly,
#  Roya Aviation,
#  The Paper Cup Factory,
#  Nielson Nigeria,
#  KRALOMOC,
#  Life Touch EMS,
#  Catalyst Pest,
#  Advantage Research,
#  Innormax,
#  Nu-Core,
#  David Russell Associates - Advisors in Plastics,
#  Eagles Rest RV,
#  Shifa Herb,
#  Starmus,
#  Strobel Trucking,
#  KM Surveying,
#  Arabian Lubricants,
#  BURN NATION,
#  Wild Warrior Adventure,
#  Dripcolor,
#  SA Precious Metals,
#  Birth Kalamazoo,
#  AEROFORM,
#  Forever Custom Tattoos,
#  Modern Furniture,
#  Weisshaar,
#  The Barkery,
#  Mile High Sounds,
#  Puvi,
#  Plastics Distributors,
#  Southampton Trust Bank,
#  Sharedband Limited,
#  Tamanend,
#  Tinting Company,
#  Tailomy,
#  VA Mortgages,
#  MYE Technologies,
#  Lund-Ross,
#  Sensual Souls,
#  Aspect Garden Solutions,
#  RevEssentials,
#  Red Carpet Towing,
#  The Joint Venture,
#  Alive Church Systems,
#  DNA UK PROPERTIES,
#  Mold Removal and Remediation,
#  ZONEGEN,
#  Galveston Golf Carts,
#  KLJ Computer Solutions,
#  Premier Home Inspections,
#  Mowers Parts,
#  RSS DiMed,
#  Afzal Wholesale,
#  Actual Food Nashville,
#  Part fruits,
#  West Auckland Storage,
#  Tulsa Winch,
#  Trip the Fan,
#  Holder Industrial,
#  Ditto Africa,
#  Rag and Co Store,
#  Imoedo,
#  South West Truck & Trailer Parts,
#  Cookie Bear Baking,
#  Scooters London,
#  Ealing UG,
#  Still Pond,
#  ADITYA NONWOVEN FABRIC,
#  M.Ahari Plant,
#  QWIL Investments,
#  Johnson Construction Clearing,
#  Canadian Energy Equipment Manufacturing FZ-LLC,
#  Alien Logistics,
#  GF Compressors,
#  Launceston Engineering,
#  Parent Law,
#  Somerset County Film Commission,
#  Shail International Private Limited,
#  Garcia Pharmacy Discount,
#  Pitch Perfect Events,
#  Oracle Home Inspections,
#  Peak Performance Footwear,
#  Inekar,
#  Kayton Travel,
#  DFC Wood Products,
#  DOG EAT CAKE,
#  NetZeroAg,
#  Via-Tech Sierra Leone,
#  First Rate Appliance Repair,
#  Advanced Tech Installations,
#  Radleymotorco,
#  Quality Custom Kitchen,
#  MOIM,
#  Kwokote Enterprises,
#  The Rustic Wood Man,
#  EKOENERGETIKA,
#  Lighting & Signs,
#  Fairwyn,
#  Exitact,
#  Stonebridge Imports,
#  Sullo Engineering,
#  Gettinright Mobile Car Wash And Detailing,
#  R&T KLEAN UP KINGS,
#  World Learning,
#  Rocbit,
#  Lemon Pavilion,
#  Supponor,
#  CALINC Services,
#  Bridges Catering,
#  EXIGENT,
#  Mr. Chips,
#  LUX LANDSCAPE LIGHTING,
#  Bomber Music,
#  Midwest Servicing Group,
#  Edaji,
#  Heavy Duty Transaxle,
#  Wolf Willow Studios,
#  Victoria Pacific,
#  Spin Ghar Travel & Tours,
#  Workvenue,
#  Farmers' Markets of Nova Scotia,
#  The Holt Trust,
#  R. W. PLADSEN,
#  Jolley's Trailer Sales,
#  Regina Performing Arts Centre,
#  Nick Munro,
#  Go Marketing,
#  Amtec Medical,
#  Elite Solution Experts,
#  Hexagon Marine,
#  International Digital News,
#  Vail Limousine,
#  DearSabah,
#  Standard Textile Home,
#  Meramec Secure,
#  Strategy Life,
#  Supreme Steel Pipe,
#  BIG BALE FLAKER,
#  Sleepy Hollow Kitchens and Baths,
#  Observation Wheel UK,
#  Carol Lang,
#  Modern Meat,
#  Jeta Gardens,
#  WDG,
#  Trident Texofab,
#  ANM Motors,
#  MVP Advisory Group,
#  BL Cosmetology School,
#  MaterialSeeker,
#  Expro Tiling,
#  Pyroflame,
#  Trinity Title,
#  Aerobiotix,
#  Wellness Expos of Canada,
#  Regal Funding,
#  Fresh Pasta Delights,
#  Seaside Movers,
#  Radformation,
#  Silk Road Auto,
#  Jamdots Baking,
#  Triple Pole Electrics,
#  SJ Equine Designer,
#  Royal Caridea,
#  Braka,
#  SHAALEK,
#  Sheds Nashville,
#  Brieda Cabins,
#  CSD Activity Camps,
#  Rubatech manufacturing,
#  Big Apple Children,
#  Syscon,
#  FinHance,
#  Sweet Touch Treats,
#  Demarest,
#  Artistic Concrete Group,
#  Advanced Technology Resources,
#  Gesky,
#  ARIHANT RASAYAN,
#  MAI Computing,
#  Syndesy Technologies,
#  FEMVO IMPERIALS,
#  Cal-ICWA,
#  Fostering Bridges,
#  United Recycle Services,
#  Circular Venture Lab,
#  Southern Comfort Psychiatric,
#  Diversified Fluid Solutions,
#  Team One Steel,
#  Yak9 Chews,
#  Musiea,
#  Walden Carpets,
#  MD DARIO,
#  KICKING MULE,
#  Discover Scuba,
#  Copier Parts,
#  Waterfall Yoga Therapy,
#  Cape Town Exotic Mushrooms,
#  The IMUTHIS Project,
#  Techno Title,
#  Universal Logistics,
#  Umamba,
#  Grandview Park Cemetery,
#  Al Saad Group,
#  STX Service Americas,
#  Express Controls,
#  Bookcliff Country Club,
#  Avvenue,
#  Bangalamukhi,
#  SOEDESCO,
#  Steele products,
#  IARSAC,
#  Zala Machine,
#  MusoMinds,
#  RAM Universal,
#  Coastal Bend Hearing,
#  Pelland Organ,
#  Rent a Yacht,
#  Batra Machinery Stores,
#  Health-Full Horizons,
#  OfferAny,
#  Broken String Guitars,
#  Aughey Screens,
#  Ceylon Foods Exports,
#  Express Printing,
#  Gioco Libero,
#  HaloSites,
#  India Futuristic Marine Pvt. Ltd.,
#  WPX,
#  GP Legal Recruitment,
#  Qurencia,
#  AWOL Brewery,
#  Merit Joinery,
#  Sea Music Company,
#  Sherri Chemicals,
#  Abaco,
#  Onstage Audio,
#  Boxpac,
#  PotterWoods Furniture,
#  Amran,
#  Stride Therapy,
#  Mama Emma Provision Store,
#  Winchester Garage Doors,
#  Plunk,
#  Pedal Action BMX,
#  Neo Water System,
#  Art of Photography Show,
#  Fajr Al Aamarat Project,
#  Absolute Carpentry,
#  Hangzhou Mao,
#  Healy Restoration,
#  Mount Prospect Self Storage,
#  Yellowhorse,
#  Capital Music Consignments,
#  C&C Home,
#  National University Of Art Education,
#  OMI VINYL,
#  MIGHTY LOVE HOME CARE INC.,
#  ChaoFeng,
#  Shoeegolovers,
#  Stamping 313,
#  Maple Plus,
#  Wonda Clothing,
#  1891 Original Tattoo,
#  Cymbo,
#  COHPS,
#  Wroffer,
#  Varuna Marine,
#  SPECIAL STEEL,
#  Recovery Shop,
#  Uncle Sam's Healthcare,
#  The Daughtry Family,
#  Mango computer & IT solutions Pvt. Ltd.,
#  Truck Deck,
#  ...]

# %%
test_df["clean_r1"] = test_df["round_1"].apply(
    lambda x: clean_text(x)
)

test_df["description_vector"] = test_df["clean_r1"].apply(nlp)

# %%
test_df["best_match_label_index"] = test_df["description_vector"].apply(
    lambda x: find_best_match(x, label_vectors)
)

# Map the index to the actual domain name
test_df["best_match_label"] = test_df["best_match_label_index"].apply(
    lambda x: clean_dataset.iloc[x]["naics_label"]
)
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_6520\1673719828.py:4: UserWarning: [W008] Evaluating Doc.similarity based on empty vectors.
#   cat_desc_vec.similarity(label_desc) for label_desc in label_vectors

# %%
test_df
# Out:
#      Unnamed: 0  company_id  \
# 0             0          84
# 1             1         115
# 2             2          50
# 3             3          92
# 4             4          88
# ..          ...         ...
# 101         101          28
# 102         102         116
# 103         103           6
# 104         104          24
# 105         105           5
#
#                                                round_1  \
# 0                                        Advisory Care
# 1                                 PPK Mining Equipment
# 2                               First Tracks Lawn Care
# 3                                New Golden Furnishers
# 4                                    Lilac City Septic
# ..                                                 ...
# 101                                        Purple Pixl
# 102                                     Pasargad Jonub
# 103                            Davis Business Machines
# 104                                   High Desert Tool
# 105  Heart to Heart International is a non-profit o...
#
#                                               answer  \
# 0                621 Ambulatory Health Care Services
# 1                  213 Support Activities for Mining
# 2            561 Administrative and Support Services
# 3    337 Furniture and Related Product Manufacturing
# 4      562 Waste Management and Remediation Services
# ..                                               ...
# 101                       811 Repair and Maintenance
# 102     237 Heavy and Civil Engineering Construction
# 103          423 Merchant Wholesalers, Durable Goods
# 104   326 Plastics and Rubber Products Manufacturing
# 105                            624 Social Assistance
#
#                                                round_2  \
# 0    Hygiene Services | One-on-one Attention and Ca...
# 1    High & Low Seam Drills | Ventilation Solutions...
# 2    Weekly Mowing | Driveway Plowing Services | Mu...
# 3    Staff Task Computer Chairs Supplier | Mesh Bac...
# 4    Clean-Out Installation | Line Replacement Serv...
# ..                                                 ...
# 101  Battery Replacement | Viruses Removal | Front ...
# 102  Infrastructure Project Management | Design and...
# 103  Managed IT Services | Document Scanners | Fax ...
# 104  Aerospace Molds Supplier | Automotive Molds Di...
# 105                             Social Services & NGOs
#
#                                                round_3  \
# 0    Advisory Care is a home health care services p...
# 1    PPK Mining Equipment is the solution partner o...
# 2    First Tracks Lawn Care, LLC prides itself on p...
# 3    New Golden Furnishers Co - Manufacturer of Dou...
# 4    Lilac City Septic services residential & comme...
# ..                                                 ...
# 101  Purple Pixl offers fast & effective repair ser...
# 102  Having a brilliant background and well-trained...
# 103  Since May 13, 1963, Davis Business Machines ha...
# 104  High Desert Tool specializes in large mold man...
# 105                                     Heart to Heart
#
#                                                round_4  \
# 0    Advisory Care Pty Ltd is a company that provid...
# 1    PPK Mining Equipment is a company that special...
# 2    First Tracks Lawn Care, LLC is a lawn care com...
# 3    New Golden Furnishers Co is a furniture manufa...
# 4    Lilac City Septic Services Co is a family-owne...
# ..                                                 ...
# 101  Purple Pixl is a technology and electronics re...
# 102  Pasargad Jonub is a private joint stock compan...
# 103  Davis Business Machines is a company that has ...
# 104  High Desert Tool is a company that specializes...
# 105  Global Health Information Provider | Humanitar...
#
#                                                round_5  \
# 0                                     Home Health Care
# 1                             Mining & Gas Exploration
# 2                          Landscaping & Lawn Services
# 3                                     Office Furniture
# 4                  Garbage Collection & Waste Disposal
# ..                                                 ...
# 101                            Phone Repair & Services
# 102                         Civil Engineering Services
# 103                                    Office Supplies
# 104                         Injection Molding Services
# 105  As a healthcare nonprofit organization, Heart ...
#
#                                               clean_r1  \
# 0                                        advisory care
# 1                                 ppk mining equipment
# 2                                      track lawn care
# 3                                 new golden furnisher
# 4                                    lilac city septic
# ..                                                 ...
# 101                                        purple pixl
# 102                                     pasargad jonub
# 103                            davis business machines
# 104                                   high desert tool
# 105  heart heart international nonprofit organizati...
#
#                                     description_vector  \
# 0                                     (advisory, care)
# 1                             (ppk, mining, equipment)
# 2                                  (track, lawn, care)
# 3                             (new, golden, furnisher)
# 4                                (lilac, city, septic)
# ..                                                 ...
# 101                                     (purple, pixl)
# 102                                  (pasargad, jonub)
# 103                        (davis, business, machines)
# 104                               (high, desert, tool)
# 105  (heart, heart, international, nonprofit, organ...
#
#      best_match_label_index                                   best_match_label
# 0                    233581                                          Utilities
# 1                    488880  Securities, Commodity Contracts, and Other Fin...
# 2                    153186                    Ambulatory Health Care Services
# 3                    445889         Plastics and Rubber Products Manufacturing
# 4                    400570                        Primary Metal Manufacturing
# ..                      ...                                                ...
# 101                   75819                            Machinery Manufacturing
# 102                       0  Building Material and Garden Equipment and Sup...
# 103                  493113                        Miscellaneous Manufacturing
# 104                  340300                        Miscellaneous Manufacturing
# 105                  356386                Administrative and Support Services
#
# [106 rows x 12 columns]

# %% [markdown]
# # Round 2

# %%
test_df.to_csv("round_1_labelled.csv", index=False)

# %%
clean_dataset["business_tags_clean"] = clean_dataset["business_tags_clean"].astype(str)
clean_dataset["tags_vector"] = clean_dataset["business_tags_clean"].apply(nlp)
label_vectors = final_data["business_tags"].tolist()
label_vectors

# %%
test_df["clean_r2"] = test_df["round_2"].apply(lambda x: clean_text(x))

test_df["r2_vector"] = test_df["clean_r2"].apply(nlp)

# %%
test_df["best_match_label_index"] = test_df["r2_vector"].apply(
    lambda x: find_best_match(x, label_vectors)
)

# Map the index to the actual domain name
test_df["best_match_r2"] = test_df["best_match_label_index"].apply(
    lambda x: clean_dataset.iloc[x]["naics_label"]
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 test_df["best_match_label_index"] = test_df["r2_vector"].apply(
#       2     lambda x: find_best_match(x, label_vectors)
#       3 )
#       5 # Map the index to the actual domain name
#       6 test_df["best_match_r2"] = test_df["best_match_label_index"].apply(
#       7     lambda x: clean_dataset.iloc[x]["naics_label"]
#       8 )
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[24], line 2, in <lambda>(x)
#       1 test_df["best_match_label_index"] = test_df["r2_vector"].apply(
# ----> 2     lambda x: find_best_match(x, label_vectors)
#       3 )
#       5 # Map the index to the actual domain name
#       6 test_df["best_match_r2"] = test_df["best_match_label_index"].apply(
#       7     lambda x: clean_dataset.iloc[x]["naics_label"]
#       8 )
#
# Cell In[6], line 3, in find_best_match(cat_desc_vec, label_vectors)
#       1 def find_best_match(cat_desc_vec, label_vectors):
#       2     # Calculate similarities and return the index of the highest similarity
# ----> 3     similarities = [
#       4         cat_desc_vec.similarity(label_desc) for label_desc in label_vectors
#       5     ]
#       6     return similarities.index(max(similarities))
#
# Cell In[6], line 4, in <listcomp>(.0)
#       1 def find_best_match(cat_desc_vec, label_vectors):
#       2     # Calculate similarities and return the index of the highest similarity
#       3     similarities = [
# ----> 4         cat_desc_vec.similarity(label_desc) for label_desc in label_vectors
#       5     ]
#       6     return similarities.index(max(similarities))
#
# File c:\Users\andre\anaconda3\envs\tournament\lib\site-packages\spacy\tokens\doc.pyx:642, in spacy.tokens.doc.Doc.similarity()
#
# AttributeError: 'str' object has no attribute 'vector_norm'
